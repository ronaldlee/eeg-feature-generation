# %% [markdown]
# <h1>LSTM + CNN + MLPNN model</h1>

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' #only show errors (hide INFO and WARNING)

import numpy as np
import pandas as pd
import random
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Flatten, concatenate, Input, Dropout, LSTM, Bidirectional,BatchNormalization,PReLU,ReLU,Reshape
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Sequential, Model, load_model
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
import keras_tuner as kt

random.seed(1234)   
np.random.seed(1234)

# %% [markdown]
# <h3>Helper functions to plot loss/accuracy, and build/train/test models.</h3>

# %%
def plot_loss_history(history):
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.xticks(range(0, len(history['loss'] + 1)))
  plt.plot(history['loss'], label="training", marker='o')
  plt.plot(history['val_loss'], label="validation", marker='o')
  plt.legend()
  plt.show()

def plot_accuracy_history(history):
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.xticks(range(0, len(history['accuracy'] + 1)))
  plt.plot(history['accuracy'], label="training", marker='o')
  plt.plot(history['val_accuracy'], label="validation", marker='o')
  plt.legend()
  plt.show()

# %%
def build_model(number_of_features, dense_layers_unit_array=[], learningRate=0.001,
                activation="relu", isBatchNormalized=False, dropOutRate=0,
                startWithBatchNormalized=False,optimizer="Adam",
                conv_layers_filters_array=[],conv_kernel_size_array=[],conv_strides_array=[],
                lstm_layers_unit_array=[]
               ):
    os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
    
    strategy = tf.distribute.MirroredStrategy(devices=None)
    print('Number of GPU/CPU: {}'.format(strategy.num_replicas_in_sync))
    
    print("num_of_dense_layers:",len(dense_layers_unit_array))
    
    for i, dense_layer_unit in enumerate(dense_layers_unit_array):       
        print("dense_layer["+str(i)+"]; unit:"+str(dense_layer_unit))   
        
    print("num_of_lstm_layers:",len(lstm_layers_unit_array))    
    for i, lstm_layer_unit in enumerate(lstm_layers_unit_array):       
        print("lstm_layer_unit["+str(i)+"]; unit:"+str(lstm_layer_unit))       
        
    print("num_of_conv_layers:",len(conv_layers_filters_array))    
    for i, conv_layer_filters in enumerate(conv_layers_filters_array):       
        print("conv_layer_filters["+str(i)+"]; unit:"+str(conv_layer_filters))  
        print("conv_kernel["+str(i)+"]; unit:"+str(conv_kernel_size_array[i]))
        print("conv_strides["+str(i)+"]; unit:"+str(conv_strides_array[i]))
       
    print("learningRate:",learningRate)
    print("isBatchNormalized:",isBatchNormalized,"; dropOutRate:",dropOutRate)
    
    startWithBatchNormalized = startWithBatchNormalized or optimizer == "SGD"
    print("startWithBatchNormalized:",startWithBatchNormalized)
    print("optimizer:",optimizer,"; activation:",activation)
    
    tf.keras.backend.clear_session()
    tf.random.set_seed(1234)     
    np.random.seed(1234)
    random.seed(1234)
    
    with strategy.scope():   
        model = Sequential() 
        
        if startWithBatchNormalized:
            model.add(BatchNormalization())
         
        # Add LSTM layers
        for i, lstm_layer_unit in enumerate(lstm_layers_unit_array):    
            model.add(LSTM(lstm_layer_unit, return_sequences=True))
        
        # Add Conv layers
        for i, conv_layer_filters in enumerate(conv_layers_filters_array):    
            model.add(tf.keras.layers.Conv1D(
            filters=conv_layer_filters,                
            kernel_size=conv_kernel_size_array[i],
            strides=conv_strides_array[i],
            padding='same',
            data_format='channels_last',
            name='conv_'+str(i),
            activation='relu'))
        
            model.add(tf.keras.layers.MaxPool1D(
                pool_size=2,
                name='pool_'+str(i))) 

        if len(conv_layers_filters_array) > 0:    
            model.add(Flatten()) 
        
        # Add Dense layers
        for i, dense_layer_unit in enumerate(dense_layers_unit_array):
            model.add(tf.keras.layers.Dense(
                units=dense_layer_unit,
                name='fc_'+str(i), 
                activation=activation))
            if isBatchNormalized:
                model.add(BatchNormalization())
            if dropOutRate > 0:
                model.add(Dropout(dropOutRate))
                
        model.add(Dense(4))
        model.add(Activation('softmax'))   

        if len(conv_layers_filters_array) == 0 and len(dense_layers_unit_array) > 0 : 
            model.build(input_shape=(None, number_of_features))
        else:
            model.build(input_shape=(None, number_of_features, 1)) 

        if optimizer=="Adam":
            opt = keras.optimizers.Adam(learning_rate=learningRate)
        elif optimizer=="SGD":
            opt = keras.optimizers.SGD(learning_rate=learningRate)
        else:
            opt = keras.optimizers.Adam(learning_rate=learningRate)    
        

        model.compile(optimizer=opt,
                      loss=['categorical_crossentropy'],
                      metrics=['accuracy', keras.metrics.Precision(), keras.metrics.Recall()])    
    
    return model

# %%
def train_and_test_model(train_dataset, validate_dataset, x_train, test_dataset,
                         save_to, epoch = 2,
                         dense_layers_unit_array=[],
                         patience=10, epoch_denominator=10.,
                         isConstantLearningRate=False, learningRate=0.001,
                         activation="relu", isBatchNormalized=False,dropOutRate=0,
                         startWithBatchNormalized=False,optimizer="Adam",
                         conv_layers_filters_array=[],conv_kernel_size_array=[],conv_strides_array=[],
                         lstm_layers_unit_array=[]
                        ):
    
    print("epoch:",epoch, "; epoch_denominator:",epoch_denominator) 
    print("patience:",patience,"; isConstantLearningRate:", isConstantLearningRate) 
    
    model = build_model(x_train.shape[1],
                        dense_layers_unit_array=dense_layers_unit_array, learningRate=learningRate,
                        activation=activation, isBatchNormalized=isBatchNormalized, dropOutRate=dropOutRate,
                        startWithBatchNormalized=startWithBatchNormalized,optimizer=optimizer,
                        conv_layers_filters_array=conv_layers_filters_array,
                        conv_kernel_size_array=conv_kernel_size_array,
                        conv_strides_array=conv_strides_array,
                        lstm_layers_unit_array=lstm_layers_unit_array
                       )

    model.summary()
    tf.keras.utils.plot_model(model)  
    
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=patience)

    if isConstantLearningRate:  
        lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: learningRate)        
    else:  
        lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: learningRate * np.exp(-epoch / epoch_denominator))

    history = model.fit(train_dataset,
                        epochs=epoch,
                        validation_data=validate_dataset,
                        shuffle=True,
                        callbacks=[es,lr_schedule])

    history_data = pd.DataFrame(history.history)
    plot_loss_history(history_data)
    plot_accuracy_history(history_data)

    # test model
    test_results = model.evaluate(test_dataset)
    print('\nTest Acc. {:.2f}%'.format(test_results[1]*100))

    # show classification report
    y_predict = np.array(model.predict(test_dataset))
    y_predict = to_categorical(np.argmax(y_predict, axis=1), 4)
    print(classification_report(y_test, y_predict))
    
    print("Confusion matrix")
    print(confusion_matrix(y_test.values.argmax(axis=1), np.argmax(y_predict, axis=1)))

# %%
dataset = pd.read_csv('csv/out_gameemo.csv',  sep=',')

print('Shape of data: ', dataset.shape)
# Out:
# Shape of data:  (40071, 3739)

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

init_df = dataset.copy()

#HA_PV = high arousal, positive valence
#HA_NV = high arousal, negative valence
#LA_NV = low arousal, negative valence
#LA_PV = low arousal, positive valance
label_map = {1:"HA_PV", 2:"HA_NV", 3:"LA_NV", 4:"LA_PV"}

init_df["Label"] = init_df["Label"].map(label_map)


features = init_df.iloc[:, :-1]
label = init_df.iloc[:, -1:]

print('Shape of data: ', init_df.shape)
print('features.shape: ', features.shape)
print('label.shape: ', label.shape)

#######

y = label
X = features

X_train, X_validate, y_train, y_validate = train_test_split(X, y, train_size=0.6, random_state=48)

X_validate, X_test, y_validate, y_test = train_test_split(X_validate, y_validate, train_size=0.5, random_state=48)

X_train_for_mlpnn = X_train.copy()
X_validate_for_mlpnn = X_validate.copy()
X_test_for_mlpnn = X_test.copy()

X_train = np.array(X_train).reshape((X_train.shape[0],X_train.shape[1],1))
X_validate = np.array(X_validate).reshape((X_validate.shape[0],X_test.shape[1],1))
X_test = np.array(X_test).reshape((X_test.shape[0],X_test.shape[1],1))

y_train = pd.get_dummies(y_train)
y_validate = pd.get_dummies(y_validate)
y_test = pd.get_dummies(y_test)

print("y_train:")
print(y_train[:5])

#######
train_dataset_for_mlpnn = tf.data.Dataset.from_tensor_slices((X_train_for_mlpnn, y_train))
validate_dataset_for_mlpnn = tf.data.Dataset.from_tensor_slices((X_validate_for_mlpnn, y_validate))
test_dataset_for_mlpnn = tf.data.Dataset.from_tensor_slices((X_test_for_mlpnn, y_test))

train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
validate_dataset = tf.data.Dataset.from_tensor_slices((X_validate, y_validate))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))

options = tf.data.Options()
options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.DATA
train_dataset_for_mlpnn.with_options(options)
validate_dataset_for_mlpnn.with_options(options)
test_dataset_for_mlpnn.with_options(options)

train_dataset.with_options(options)
validate_dataset.with_options(options)
test_dataset.with_options(options)

        
batch_size = 30
train_dataset_for_mlpnn = train_dataset_for_mlpnn.batch(batch_size)
validate_dataset_for_mlpnn = validate_dataset_for_mlpnn.batch(batch_size)
test_dataset_for_mlpnn = test_dataset_for_mlpnn.batch(batch_size)

train_dataset = train_dataset.batch(batch_size)
validate_dataset = validate_dataset.batch(batch_size)
test_dataset = test_dataset.batch(batch_size)
# Out:
# Shape of data:  (40071, 3739)
# features.shape:  (40071, 3738)
# label.shape:  (40071, 1)
# y_train:
#        Label_HA_NV  Label_HA_PV  Label_LA_NV  Label_LA_PV
# 13079            1            0            0            0
# 37831            1            0            0            0
# 23516            0            0            1            0
# 10630            0            1            0            0
# 36071            0            0            1            0

# %% [markdown]
# <h3>Manual runs to get a feel of the hyperparameters</h3>

# %% [markdown]
# Start with just 1 LSTM layer on best CNN+MLPNN setup

# %%
train_and_test_model(train_dataset, validate_dataset, X_train, test_dataset, save_to= './', epoch = 40, 
                     dense_layers_unit_array=[512], learningRate=0.1,
                     startWithBatchNormalized=True, optimizer="SGD",dropOutRate=0.5,
                     activation="relu",
                     conv_layers_filters_array=[100,100,100],
                     conv_kernel_size_array=[3,3,3],
                     conv_strides_array=[1,1,1],
                     lstm_layers_unit_array=[256]
                    )
# Out:
# epoch: 40 ; epoch_denominator: 10.0
# patience: 10 ; isConstantLearningRate: False
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of GPU/CPU: 2
# num_of_dense_layers: 1
# dense_layer[0]; unit:512
# num_of_lstm_layers: 1
# lstm_layer_unit[0]; unit:256
# num_of_conv_layers: 3
# conv_layer_filters[0]; unit:100
# conv_kernel[0]; unit:3
# conv_strides[0]; unit:1
# conv_layer_filters[1]; unit:100
# conv_kernel[1]; unit:3
# conv_strides[1]; unit:1
# conv_layer_filters[2]; unit:100
# conv_kernel[2]; unit:3
# conv_strides[2]; unit:1
# learningRate: 0.1
# isBatchNormalized: False ; dropOutRate: 0.5
# startWithBatchNormalized: True
# optimizer: SGD ; activation: relu
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 3738, 1)           4
# _________________________________________________________________
# lstm (LSTM)                  (None, 3738, 256)         264192
# _________________________________________________________________
# conv_0 (Conv1D)              (None, 3738, 100)         76900
# _________________________________________________________________
# pool_0 (MaxPooling1D)        (None, 1869, 100)         0
# _________________________________________________________________
# conv_1 (Conv1D)              (None, 1869, 100)         30100
# _________________________________________________________________
# pool_1 (MaxPooling1D)        (None, 934, 100)          0
# _________________________________________________________________
# conv_2 (Conv1D)              (None, 934, 100)          30100
# _________________________________________________________________
# pool_2 (MaxPooling1D)        (None, 467, 100)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 46700)             0
# _________________________________________________________________
# fc_0 (Dense)                 (None, 512)               23910912
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 2052
# _________________________________________________________________
# activation (Activation)      (None, 4)                 0
# =================================================================
# Total params: 24,314,260
# Trainable params: 24,314,258
# Non-trainable params: 2
# _________________________________________________________________
# Epoch 1/40
# INFO:tensorflow:batch_all_reduce: 15 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 15 all-reduces with algorithm = nccl, num_packs = 1
# 802/802 [==============================] - 156s 184ms/step - loss: 1.3823 - accuracy: 0.2671 - precision: 0.2320 - recall: 8.1187e-04 - val_loss: 1.3443 - val_accuracy: 0.3434 - val_precision: 0.5028 - val_recall: 0.0332
# Epoch 2/40
# 802/802 [==============================] - 146s 183ms/step - loss: 1.2684 - accuracy: 0.4044 - precision: 0.6161 - recall: 0.0831 - val_loss: 1.1703 - val_accuracy: 0.4824 - val_precision: 0.6432 - val_recall: 0.2695
# Epoch 3/40
# 802/802 [==============================] - 146s 183ms/step - loss: 0.9924 - accuracy: 0.5657 - precision: 0.7230 - recall: 0.3642 - val_loss: 1.1307 - val_accuracy: 0.5552 - val_precision: 0.6228 - val_recall: 0.4873
# Epoch 4/40
# 802/802 [==============================] - 146s 182ms/step - loss: 0.7782 - accuracy: 0.6760 - precision: 0.7750 - recall: 0.5487 - val_loss: 0.8224 - val_accuracy: 0.6678 - val_precision: 0.7264 - val_recall: 0.6062
# Epoch 5/40
# 802/802 [==============================] - 146s 183ms/step - loss: 0.5980 - accuracy: 0.7583 - precision: 0.8243 - recall: 0.6820 - val_loss: 0.5785 - val_accuracy: 0.7669 - val_precision: 0.8219 - val_recall: 0.7001
# Epoch 6/40
# 802/802 [==============================] - 146s 183ms/step - loss: 0.4650 - accuracy: 0.8178 - precision: 0.8580 - recall: 0.7723 - val_loss: 0.5311 - val_accuracy: 0.7859 - val_precision: 0.8265 - val_recall: 0.7501
# Epoch 7/40
# 802/802 [==============================] - 146s 183ms/step - loss: 0.3405 - accuracy: 0.8704 - precision: 0.8976 - recall: 0.8444 - val_loss: 0.4507 - val_accuracy: 0.8243 - val_precision: 0.8546 - val_recall: 0.7907
# Epoch 8/40
# 802/802 [==============================] - 146s 183ms/step - loss: 0.2484 - accuracy: 0.9094 - precision: 0.9224 - recall: 0.8929 - val_loss: 0.4584 - val_accuracy: 0.8315 - val_precision: 0.8521 - val_recall: 0.8117
# Epoch 9/40
# 802/802 [==============================] - 145s 181ms/step - loss: 0.1815 - accuracy: 0.9326 - precision: 0.9431 - recall: 0.9230 - val_loss: 0.4269 - val_accuracy: 0.8454 - val_precision: 0.8628 - val_recall: 0.8297
# Epoch 10/40
# 802/802 [==============================] - 145s 181ms/step - loss: 0.1358 - accuracy: 0.9515 - precision: 0.9574 - recall: 0.9462 - val_loss: 0.4165 - val_accuracy: 0.8531 - val_precision: 0.8675 - val_recall: 0.8400
# Epoch 11/40
# 802/802 [==============================] - 145s 180ms/step - loss: 0.1031 - accuracy: 0.9634 - precision: 0.9679 - recall: 0.9592 - val_loss: 0.4466 - val_accuracy: 0.8558 - val_precision: 0.8665 - val_recall: 0.8478
# Epoch 12/40
# 802/802 [==============================] - 145s 180ms/step - loss: 0.0875 - accuracy: 0.9686 - precision: 0.9716 - recall: 0.9660 - val_loss: 0.4050 - val_accuracy: 0.8722 - val_precision: 0.8817 - val_recall: 0.8652
# Epoch 13/40
# 802/802 [==============================] - 144s 180ms/step - loss: 0.0550 - accuracy: 0.9816 - precision: 0.9836 - recall: 0.9802 - val_loss: 0.3983 - val_accuracy: 0.8768 - val_precision: 0.8847 - val_recall: 0.8707
# Epoch 14/40
# 802/802 [==============================] - 145s 180ms/step - loss: 0.0445 - accuracy: 0.9852 - precision: 0.9862 - recall: 0.9836 - val_loss: 0.4175 - val_accuracy: 0.8773 - val_precision: 0.8844 - val_recall: 0.8722
# Epoch 15/40
# 802/802 [==============================] - 145s 180ms/step - loss: 0.0399 - accuracy: 0.9880 - precision: 0.9890 - recall: 0.9864 - val_loss: 0.4220 - val_accuracy: 0.8788 - val_precision: 0.8845 - val_recall: 0.8743
# Epoch 16/40
# 802/802 [==============================] - 145s 180ms/step - loss: 0.0267 - accuracy: 0.9923 - precision: 0.9931 - recall: 0.9919 - val_loss: 0.4141 - val_accuracy: 0.8833 - val_precision: 0.8893 - val_recall: 0.8793
# Epoch 17/40
# 802/802 [==============================] - 145s 180ms/step - loss: 0.0231 - accuracy: 0.9930 - precision: 0.9935 - recall: 0.9922 - val_loss: 0.4203 - val_accuracy: 0.8851 - val_precision: 0.8902 - val_recall: 0.8806
# Epoch 18/40
# 802/802 [==============================] - 145s 180ms/step - loss: 0.0189 - accuracy: 0.9938 - precision: 0.9939 - recall: 0.9930 - val_loss: 0.4092 - val_accuracy: 0.8873 - val_precision: 0.8918 - val_recall: 0.8827
# Epoch 19/40
# 802/802 [==============================] - 145s 181ms/step - loss: 0.0169 - accuracy: 0.9944 - precision: 0.9951 - recall: 0.9944 - val_loss: 0.4132 - val_accuracy: 0.8868 - val_precision: 0.8920 - val_recall: 0.8838
# Epoch 20/40
# 802/802 [==============================] - 145s 181ms/step - loss: 0.0171 - accuracy: 0.9949 - precision: 0.9950 - recall: 0.9946 - val_loss: 0.4116 - val_accuracy: 0.8879 - val_precision: 0.8918 - val_recall: 0.8845
# Epoch 21/40
# 802/802 [==============================] - 145s 180ms/step - loss: 0.0131 - accuracy: 0.9958 - precision: 0.9959 - recall: 0.9957 - val_loss: 0.4275 - val_accuracy: 0.8872 - val_precision: 0.8911 - val_recall: 0.8832
# Epoch 22/40
# 802/802 [==============================] - 145s 180ms/step - loss: 0.0098 - accuracy: 0.9971 - precision: 0.9972 - recall: 0.9970 - val_loss: 0.4437 - val_accuracy: 0.8877 - val_precision: 0.8915 - val_recall: 0.8852
# Epoch 23/40
# 802/802 [==============================] - 144s 180ms/step - loss: 0.0103 - accuracy: 0.9971 - precision: 0.9972 - recall: 0.9971 - val_loss: 0.4200 - val_accuracy: 0.8901 - val_precision: 0.8929 - val_recall: 0.8866
# Epoch 00023: early stopping
# 268/268 [==============================] - 17s 64ms/step - loss: 0.4036 - accuracy: 0.8963 - precision: 0.8987 - recall: 0.8934
#
# Test Acc. 89.63%
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88      1978
#            1       0.90      0.90      0.90      1957
#            2       0.93      0.91      0.92      2069
#            3       0.89      0.88      0.88      2011
#
#    micro avg       0.90      0.90      0.90      8015
#    macro avg       0.90      0.90      0.90      8015
# weighted avg       0.90      0.90      0.90      8015
#  samples avg       0.90      0.90      0.90      8015
#
# Confusion matrix
# [[1751  112   38   77]
#  [ 114 1771   22   50]
#  [  45   32 1893   99]
#  [  95   56   91 1769]]

# %%
train_and_test_model(train_dataset, validate_dataset, X_train, test_dataset, save_to= './', epoch = 40, 
                     dense_layers_unit_array=[512], learningRate=0.1,
                     startWithBatchNormalized=True, optimizer="SGD",dropOutRate=0.2,
                     activation="relu",
                     conv_layers_filters_array=[100,100,100],
                     conv_kernel_size_array=[3,3,3],
                     conv_strides_array=[1,1,1],
                     lstm_layers_unit_array=[256]
                    )
# Out:
# epoch: 40 ; epoch_denominator: 10.0
# patience: 10 ; isConstantLearningRate: False
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of GPU/CPU: 2
# num_of_dense_layers: 1
# dense_layer[0]; unit:512
# num_of_lstm_layers: 1
# lstm_layer_unit[0]; unit:256
# num_of_conv_layers: 3
# conv_layer_filters[0]; unit:100
# conv_kernel[0]; unit:3
# conv_strides[0]; unit:1
# conv_layer_filters[1]; unit:100
# conv_kernel[1]; unit:3
# conv_strides[1]; unit:1
# conv_layer_filters[2]; unit:100
# conv_kernel[2]; unit:3
# conv_strides[2]; unit:1
# learningRate: 0.1
# isBatchNormalized: False ; dropOutRate: 0.2
# startWithBatchNormalized: True
# optimizer: SGD ; activation: relu
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 3738, 1)           4
# _________________________________________________________________
# lstm (LSTM)                  (None, 3738, 256)         264192
# _________________________________________________________________
# conv_0 (Conv1D)              (None, 3738, 100)         76900
# _________________________________________________________________
# pool_0 (MaxPooling1D)        (None, 1869, 100)         0
# _________________________________________________________________
# conv_1 (Conv1D)              (None, 1869, 100)         30100
# _________________________________________________________________
# pool_1 (MaxPooling1D)        (None, 934, 100)          0
# _________________________________________________________________
# conv_2 (Conv1D)              (None, 934, 100)          30100
# _________________________________________________________________
# pool_2 (MaxPooling1D)        (None, 467, 100)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 46700)             0
# _________________________________________________________________
# fc_0 (Dense)                 (None, 512)               23910912
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 2052
# _________________________________________________________________
# activation (Activation)      (None, 4)                 0
# =================================================================
# Total params: 24,314,260
# Trainable params: 24,314,258
# Non-trainable params: 2
# _________________________________________________________________
# Epoch 1/40
# INFO:tensorflow:batch_all_reduce: 15 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 15 all-reduces with algorithm = nccl, num_packs = 1
# 802/802 [==============================] - 152s 183ms/step - loss: 1.3790 - accuracy: 0.2746 - precision: 0.2836 - recall: 0.0018 - val_loss: 1.3365 - val_accuracy: 0.3569 - val_precision: 0.5643 - val_recall: 0.0575
# Epoch 2/40
# 802/802 [==============================] - 145s 180ms/step - loss: 1.2117 - accuracy: 0.4436 - precision: 0.6389 - recall: 0.1417 - val_loss: 1.1064 - val_accuracy: 0.5061 - val_precision: 0.6824 - val_recall: 0.3172
# Epoch 3/40
# 802/802 [==============================] - 145s 181ms/step - loss: 0.8926 - accuracy: 0.6218 - precision: 0.7561 - recall: 0.4551 - val_loss: 1.0001 - val_accuracy: 0.6079 - val_precision: 0.6733 - val_recall: 0.5356
# Epoch 4/40
# 802/802 [==============================] - 146s 182ms/step - loss: 0.6472 - accuracy: 0.7337 - precision: 0.8038 - recall: 0.6459 - val_loss: 0.6886 - val_accuracy: 0.7298 - val_precision: 0.7773 - val_recall: 0.6782
# Epoch 5/40
# 802/802 [==============================] - 146s 183ms/step - loss: 0.4453 - accuracy: 0.8243 - precision: 0.8628 - recall: 0.7832 - val_loss: 0.5376 - val_accuracy: 0.7904 - val_precision: 0.8265 - val_recall: 0.7557
# Epoch 6/40
# 802/802 [==============================] - 148s 184ms/step - loss: 0.2919 - accuracy: 0.8873 - precision: 0.9084 - recall: 0.8687 - val_loss: 0.5894 - val_accuracy: 0.7799 - val_precision: 0.8014 - val_recall: 0.7608
# Epoch 7/40
# 802/802 [==============================] - 148s 184ms/step - loss: 0.1883 - accuracy: 0.9299 - precision: 0.9417 - recall: 0.9206 - val_loss: 0.4562 - val_accuracy: 0.8315 - val_precision: 0.8505 - val_recall: 0.8123
# Epoch 8/40
# 802/802 [==============================] - 148s 184ms/step - loss: 0.1166 - accuracy: 0.9594 - precision: 0.9646 - recall: 0.9539 - val_loss: 0.4669 - val_accuracy: 0.8505 - val_precision: 0.8598 - val_recall: 0.8384
# Epoch 9/40
# 802/802 [==============================] - 148s 185ms/step - loss: 0.0851 - accuracy: 0.9706 - precision: 0.9745 - recall: 0.9679 - val_loss: 0.4642 - val_accuracy: 0.8513 - val_precision: 0.8624 - val_recall: 0.8428
# Epoch 10/40
# 802/802 [==============================] - 148s 184ms/step - loss: 0.0503 - accuracy: 0.9842 - precision: 0.9854 - recall: 0.9828 - val_loss: 0.4620 - val_accuracy: 0.8699 - val_precision: 0.8764 - val_recall: 0.8629
# Epoch 11/40
# 802/802 [==============================] - 148s 184ms/step - loss: 0.0403 - accuracy: 0.9872 - precision: 0.9883 - recall: 0.9866 - val_loss: 0.5290 - val_accuracy: 0.8553 - val_precision: 0.8618 - val_recall: 0.8511
# Epoch 12/40
# 802/802 [==============================] - 148s 185ms/step - loss: 0.0266 - accuracy: 0.9916 - precision: 0.9921 - recall: 0.9912 - val_loss: 0.4822 - val_accuracy: 0.8689 - val_precision: 0.8747 - val_recall: 0.8659
# Epoch 13/40
# 802/802 [==============================] - 148s 184ms/step - loss: 0.0175 - accuracy: 0.9946 - precision: 0.9951 - recall: 0.9944 - val_loss: 0.5062 - val_accuracy: 0.8681 - val_precision: 0.8727 - val_recall: 0.8636
# Epoch 14/40
# 802/802 [==============================] - 148s 185ms/step - loss: 0.0133 - accuracy: 0.9968 - precision: 0.9969 - recall: 0.9967 - val_loss: 0.4976 - val_accuracy: 0.8738 - val_precision: 0.8771 - val_recall: 0.8699
# Epoch 15/40
# 802/802 [==============================] - 148s 184ms/step - loss: 0.0081 - accuracy: 0.9982 - precision: 0.9982 - recall: 0.9982 - val_loss: 0.5128 - val_accuracy: 0.8736 - val_precision: 0.8786 - val_recall: 0.8714
# Epoch 16/40
# 802/802 [==============================] - 145s 181ms/step - loss: 0.0064 - accuracy: 0.9988 - precision: 0.9988 - recall: 0.9986 - val_loss: 0.5014 - val_accuracy: 0.8813 - val_precision: 0.8845 - val_recall: 0.8786
# Epoch 17/40
# 802/802 [==============================] - 145s 180ms/step - loss: 0.0052 - accuracy: 0.9989 - precision: 0.9989 - recall: 0.9988 - val_loss: 0.5099 - val_accuracy: 0.8792 - val_precision: 0.8829 - val_recall: 0.8758
# Epoch 00017: early stopping
# 268/268 [==============================] - 18s 64ms/step - loss: 0.4827 - accuracy: 0.8843 - precision: 0.8881 - recall: 0.8823
#
# Test Acc. 88.43%
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86      1978
#            1       0.89      0.91      0.90      1957
#            2       0.92      0.91      0.92      2069
#            3       0.86      0.87      0.87      2011
#
#    micro avg       0.88      0.88      0.88      8015
#    macro avg       0.88      0.88      0.88      8015
# weighted avg       0.88      0.88      0.88      8015
#  samples avg       0.88      0.88      0.88      8015
#
# Confusion matrix
# [[1672  129   38  139]
#  [  99 1776   21   61]
#  [  60   40 1889   80]
#  [ 102   60   98 1751]]

# %%
train_and_test_model(train_dataset, validate_dataset, X_train, test_dataset, save_to= './', epoch = 40, 
                     dense_layers_unit_array=[512], learningRate=0.1,
                     startWithBatchNormalized=True, optimizer="SGD",dropOutRate=0.8,
                     activation="relu",
                     conv_layers_filters_array=[100,100,100],
                     conv_kernel_size_array=[3,3,3],
                     conv_strides_array=[1,1,1],
                     lstm_layers_unit_array=[256]
                    )
# Out:
# epoch: 40 ; epoch_denominator: 10.0
# patience: 10 ; isConstantLearningRate: False
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of GPU/CPU: 2
# num_of_dense_layers: 1
# dense_layer[0]; unit:512
# num_of_lstm_layers: 1
# lstm_layer_unit[0]; unit:256
# num_of_conv_layers: 3
# conv_layer_filters[0]; unit:100
# conv_kernel[0]; unit:3
# conv_strides[0]; unit:1
# conv_layer_filters[1]; unit:100
# conv_kernel[1]; unit:3
# conv_strides[1]; unit:1
# conv_layer_filters[2]; unit:100
# conv_kernel[2]; unit:3
# conv_strides[2]; unit:1
# learningRate: 0.1
# isBatchNormalized: False ; dropOutRate: 0.8
# startWithBatchNormalized: True
# optimizer: SGD ; activation: relu
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 3738, 1)           4
# _________________________________________________________________
# lstm (LSTM)                  (None, 3738, 256)         264192
# _________________________________________________________________
# conv_0 (Conv1D)              (None, 3738, 100)         76900
# _________________________________________________________________
# pool_0 (MaxPooling1D)        (None, 1869, 100)         0
# _________________________________________________________________
# conv_1 (Conv1D)              (None, 1869, 100)         30100
# _________________________________________________________________
# pool_1 (MaxPooling1D)        (None, 934, 100)          0
# _________________________________________________________________
# conv_2 (Conv1D)              (None, 934, 100)          30100
# _________________________________________________________________
# pool_2 (MaxPooling1D)        (None, 467, 100)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 46700)             0
# _________________________________________________________________
# fc_0 (Dense)                 (None, 512)               23910912
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 2052
# _________________________________________________________________
# activation (Activation)      (None, 4)                 0
# =================================================================
# Total params: 24,314,260
# Trainable params: 24,314,258
# Non-trainable params: 2
# _________________________________________________________________
# Epoch 1/40
# INFO:tensorflow:batch_all_reduce: 15 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 15 all-reduces with algorithm = nccl, num_packs = 1
# 802/802 [==============================] - 153s 184ms/step - loss: 1.3870 - accuracy: 0.2570 - precision: 0.0579 - recall: 2.4714e-05 - val_loss: 1.3794 - val_accuracy: 0.2544 - val_precision: 0.3846 - val_recall: 0.0012
# Epoch 2/40
# 802/802 [==============================] - 146s 182ms/step - loss: 1.3668 - accuracy: 0.2944 - precision: 0.4842 - recall: 0.0066 - val_loss: 1.3142 - val_accuracy: 0.3681 - val_precision: 0.5589 - val_recall: 0.0634
# Epoch 3/40
# 802/802 [==============================] - 146s 182ms/step - loss: 1.2541 - accuracy: 0.4076 - precision: 0.6212 - recall: 0.0977 - val_loss: 1.1564 - val_accuracy: 0.4698 - val_precision: 0.6534 - val_recall: 0.2514
# Epoch 4/40
# 802/802 [==============================] - 145s 181ms/step - loss: 1.0503 - accuracy: 0.5296 - precision: 0.7031 - recall: 0.3106 - val_loss: 0.9559 - val_accuracy: 0.5906 - val_precision: 0.7291 - val_recall: 0.4362
# Epoch 5/40
# 802/802 [==============================] - 146s 182ms/step - loss: 0.8790 - accuracy: 0.6283 - precision: 0.7571 - recall: 0.4641 - val_loss: 0.7869 - val_accuracy: 0.6657 - val_precision: 0.7808 - val_recall: 0.5297
# Epoch 6/40
# 802/802 [==============================] - 146s 182ms/step - loss: 0.7510 - accuracy: 0.6859 - precision: 0.7856 - recall: 0.5632 - val_loss: 0.7585 - val_accuracy: 0.6846 - val_precision: 0.7730 - val_recall: 0.5877
# Epoch 7/40
# 802/802 [==============================] - 146s 182ms/step - loss: 0.6432 - accuracy: 0.7333 - precision: 0.8115 - recall: 0.6446 - val_loss: 0.6452 - val_accuracy: 0.7403 - val_precision: 0.8170 - val_recall: 0.6341
# Epoch 8/40
# 802/802 [==============================] - 147s 184ms/step - loss: 0.5500 - accuracy: 0.7832 - precision: 0.8405 - recall: 0.7141 - val_loss: 0.5778 - val_accuracy: 0.7697 - val_precision: 0.8179 - val_recall: 0.7140
# Epoch 9/40
# 802/802 [==============================] - 147s 184ms/step - loss: 0.4831 - accuracy: 0.8058 - precision: 0.8544 - recall: 0.7521 - val_loss: 0.5283 - val_accuracy: 0.7900 - val_precision: 0.8381 - val_recall: 0.7346
# Epoch 10/40
# 802/802 [==============================] - 148s 184ms/step - loss: 0.4053 - accuracy: 0.8404 - precision: 0.8781 - recall: 0.7976 - val_loss: 0.4704 - val_accuracy: 0.8141 - val_precision: 0.8554 - val_recall: 0.7724
# Epoch 11/40
# 802/802 [==============================] - 148s 184ms/step - loss: 0.3609 - accuracy: 0.8602 - precision: 0.8884 - recall: 0.8276 - val_loss: 0.4277 - val_accuracy: 0.8402 - val_precision: 0.8774 - val_recall: 0.7921
# Epoch 12/40
# 802/802 [==============================] - 148s 185ms/step - loss: 0.3068 - accuracy: 0.8838 - precision: 0.9052 - recall: 0.8604 - val_loss: 0.4397 - val_accuracy: 0.8335 - val_precision: 0.8638 - val_recall: 0.8020
# Epoch 13/40
# 802/802 [==============================] - 148s 185ms/step - loss: 0.2615 - accuracy: 0.8992 - precision: 0.9166 - recall: 0.8807 - val_loss: 0.4172 - val_accuracy: 0.8469 - val_precision: 0.8679 - val_recall: 0.8197
# Epoch 14/40
# 802/802 [==============================] - 148s 185ms/step - loss: 0.2275 - accuracy: 0.9116 - precision: 0.9265 - recall: 0.8987 - val_loss: 0.3881 - val_accuracy: 0.8565 - val_precision: 0.8768 - val_recall: 0.8333
# Epoch 15/40
# 802/802 [==============================] - 148s 184ms/step - loss: 0.1976 - accuracy: 0.9248 - precision: 0.9356 - recall: 0.9128 - val_loss: 0.3969 - val_accuracy: 0.8548 - val_precision: 0.8713 - val_recall: 0.8382
# Epoch 16/40
# 802/802 [==============================] - 145s 180ms/step - loss: 0.1735 - accuracy: 0.9343 - precision: 0.9442 - recall: 0.9234 - val_loss: 0.3620 - val_accuracy: 0.8681 - val_precision: 0.8851 - val_recall: 0.8509
# Epoch 17/40
# 802/802 [==============================] - 145s 180ms/step - loss: 0.1444 - accuracy: 0.9459 - precision: 0.9551 - recall: 0.9383 - val_loss: 0.3807 - val_accuracy: 0.8664 - val_precision: 0.8792 - val_recall: 0.8516
# Epoch 18/40
# 802/802 [==============================] - 145s 180ms/step - loss: 0.1220 - accuracy: 0.9555 - precision: 0.9621 - recall: 0.9491 - val_loss: 0.3628 - val_accuracy: 0.8717 - val_precision: 0.8831 - val_recall: 0.8591
# Epoch 19/40
# 802/802 [==============================] - 145s 180ms/step - loss: 0.1125 - accuracy: 0.9596 - precision: 0.9658 - recall: 0.9529 - val_loss: 0.3529 - val_accuracy: 0.8766 - val_precision: 0.8882 - val_recall: 0.8665
# Epoch 20/40
# 802/802 [==============================] - 145s 181ms/step - loss: 0.0970 - accuracy: 0.9657 - precision: 0.9694 - recall: 0.9613 - val_loss: 0.3789 - val_accuracy: 0.8747 - val_precision: 0.8834 - val_recall: 0.8670
# Epoch 21/40
# 802/802 [==============================] - 146s 182ms/step - loss: 0.0862 - accuracy: 0.9689 - precision: 0.9737 - recall: 0.9655 - val_loss: 0.3720 - val_accuracy: 0.8776 - val_precision: 0.8850 - val_recall: 0.8682
# Epoch 22/40
# 802/802 [==============================] - 146s 182ms/step - loss: 0.0748 - accuracy: 0.9734 - precision: 0.9769 - recall: 0.9705 - val_loss: 0.3578 - val_accuracy: 0.8817 - val_precision: 0.8919 - val_recall: 0.8727
# Epoch 23/40
# 802/802 [==============================] - 146s 182ms/step - loss: 0.0717 - accuracy: 0.9743 - precision: 0.9768 - recall: 0.9716 - val_loss: 0.3552 - val_accuracy: 0.8861 - val_precision: 0.8938 - val_recall: 0.8790
# Epoch 24/40
# 802/802 [==============================] - 144s 180ms/step - loss: 0.0648 - accuracy: 0.9748 - precision: 0.9776 - recall: 0.9723 - val_loss: 0.3615 - val_accuracy: 0.8828 - val_precision: 0.8916 - val_recall: 0.8751
# Epoch 25/40
# 802/802 [==============================] - 144s 180ms/step - loss: 0.0563 - accuracy: 0.9804 - precision: 0.9823 - recall: 0.9782 - val_loss: 0.3736 - val_accuracy: 0.8833 - val_precision: 0.8911 - val_recall: 0.8783
# Epoch 26/40
# 802/802 [==============================] - 144s 180ms/step - loss: 0.0524 - accuracy: 0.9830 - precision: 0.9846 - recall: 0.9806 - val_loss: 0.3631 - val_accuracy: 0.8886 - val_precision: 0.8947 - val_recall: 0.8836
# Epoch 27/40
# 802/802 [==============================] - 144s 180ms/step - loss: 0.0457 - accuracy: 0.9842 - precision: 0.9860 - recall: 0.9829 - val_loss: 0.3573 - val_accuracy: 0.8898 - val_precision: 0.8964 - val_recall: 0.8842
# Epoch 28/40
# 802/802 [==============================] - 144s 180ms/step - loss: 0.0507 - accuracy: 0.9821 - precision: 0.9834 - recall: 0.9805 - val_loss: 0.3602 - val_accuracy: 0.8902 - val_precision: 0.8967 - val_recall: 0.8857
# Epoch 29/40
# 802/802 [==============================] - 144s 180ms/step - loss: 0.0420 - accuracy: 0.9863 - precision: 0.9879 - recall: 0.9842 - val_loss: 0.3611 - val_accuracy: 0.8931 - val_precision: 0.8984 - val_recall: 0.8894
# Epoch 00029: early stopping
# 268/268 [==============================] - 17s 63ms/step - loss: 0.3555 - accuracy: 0.8926 - precision: 0.8981 - recall: 0.8885
#
# Test Acc. 89.26%
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      1978
#            1       0.89      0.90      0.90      1957
#            2       0.92      0.91      0.92      2069
#            3       0.88      0.89      0.89      2011
#
#    micro avg       0.89      0.89      0.89      8015
#    macro avg       0.89      0.89      0.89      8015
# weighted avg       0.89      0.89      0.89      8015
#  samples avg       0.89      0.89      0.89      8015
#
# Confusion matrix
# [[1711  138   43   86]
#  [ 103 1770   32   52]
#  [  48   36 1890   95]
#  [  91   52   85 1783]]

# %% [markdown]
# <h3>Hyperparam tuning on LSTM + CNN + MLPNN</h3>

# %%
number_of_features = X_train.shape[1]

def model_tuner(hp):
    print("number_of_features:", number_of_features)
    
    dense_layers_unit_array = [512]
    
    
    conv_layers_filters_array=[100,100,100]
    conv_kernel_size_array=[3,3,3]
    conv_strides_array=[1,1,1]
    
    lstm_layers_unit_array=[]
    
    lstm_layers_unit_array_size = hp.Int('lstm_layers_unit_array_size', min_value=1, max_value=2, step=1)
    for i in range(lstm_layers_unit_array_size):
        lstm_layers_unit_array.append(hp.Int('lstm_layers_unit_'+str(i), 
                                                min_value=128, max_value=512, step=64))
    
    model = build_model(number_of_features, 
                dense_layers_unit_array=dense_layers_unit_array, 
                learningRate=0.1,
                activation="relu", 
                isBatchNormalized=False, 
                dropOutRate=0.5,
                startWithBatchNormalized=True,      
                optimizer="SGD",   
                conv_layers_filters_array=conv_layers_filters_array,
                conv_kernel_size_array=conv_kernel_size_array,
                conv_strides_array=conv_strides_array,
                lstm_layers_unit_array=lstm_layers_unit_array
                       )
    
    return model

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

tuner = kt.Hyperband(model_tuner,
                     objective='val_accuracy',
                     max_epochs=40,
                     factor=3,
                     directory='.',
                     seed=1234,
                     project_name='eeg')

epochs = 40

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)


tuner.search(train_dataset, 
             epochs=epochs, 
             validation_data=validate_dataset,
             shuffle=True,
             callbacks=[stop_early])

best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]


print("#########################################")
print("")


model = tuner.hypermodel.build(best_hps)
history = model.fit(train_dataset, 
             epochs=epochs, 
             validation_data=validate_dataset,
             shuffle=True,
             callbacks=[stop_early])

history_data = pd.DataFrame(history.history)
plot_loss_history(history_data)
plot_accuracy_history(history_data)

# test model
test_results = model.evaluate(test_dataset)
print('\nTest Acc. {:.2f}%'.format(test_results[1]*100))

# show classification report
y_predict = np.array(model.predict(test_dataset))
y_predict = to_categorical(np.argmax(y_predict, axis=1), 4)
print(classification_report(y_test, y_predict))

print("Confusion matrix")
print(confusion_matrix(y_test.values.argmax(axis=1), np.argmax(y_predict, axis=1)))
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./eeg/oracle.json
# number_of_features: 3738
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of GPU/CPU: 2
# num_of_dense_layers: 1
# dense_layer[0]; unit:512
# num_of_lstm_layers: 0
# num_of_conv_layers: 3
# conv_layer_filters[0]; unit:100
# conv_kernel[0]; unit:3
# conv_strides[0]; unit:1
# conv_layer_filters[1]; unit:100
# conv_kernel[1]; unit:3
# conv_strides[1]; unit:1
# conv_layer_filters[2]; unit:100
# conv_kernel[2]; unit:3
# conv_strides[2]; unit:1
# learningRate: 0.1
# isBatchNormalized: False ; dropOutRate: 0.5
# startWithBatchNormalized: True
# optimizer: SGD ; activation: relu
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reloading Tuner from ./eeg/tuner0.json
# INFO:tensorflow:Oracle triggered exit
# #########################################
#
# number_of_features: 3738
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of GPU/CPU: 2
# num_of_dense_layers: 1
# dense_layer[0]; unit:512
# num_of_lstm_layers: 0
# num_of_conv_layers: 3
# conv_layer_filters[0]; unit:100
# conv_kernel[0]; unit:3
# conv_strides[0]; unit:1
# conv_layer_filters[1]; unit:100
# conv_kernel[1]; unit:3
# conv_strides[1]; unit:1
# conv_layer_filters[2]; unit:100
# conv_kernel[2]; unit:3
# conv_strides[2]; unit:1
# learningRate: 0.1
# isBatchNormalized: False ; dropOutRate: 0.5
# startWithBatchNormalized: True
# optimizer: SGD ; activation: relu
# Epoch 1/40
# INFO:tensorflow:batch_all_reduce: 12 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 12 all-reduces with algorithm = nccl, num_packs = 1
# 802/802 [==============================] - 22s 20ms/step - loss: 1.3672 - accuracy: 0.3063 - precision: 0.4648 - recall: 0.0178 - val_loss: 1.2318 - val_accuracy: 0.4410 - val_precision: 0.7334 - val_recall: 0.1019
# Epoch 2/40
# 802/802 [==============================] - 14s 17ms/step - loss: 1.1165 - accuracy: 0.5069 - precision: 0.7054 - recall: 0.2409 - val_loss: 1.1042 - val_accuracy: 0.5303 - val_precision: 0.6716 - val_recall: 0.3767
# Epoch 3/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.8962 - accuracy: 0.6245 - precision: 0.7525 - recall: 0.4517 - val_loss: 0.8222 - val_accuracy: 0.6603 - val_precision: 0.7724 - val_recall: 0.5353
# Epoch 4/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.7435 - accuracy: 0.6958 - precision: 0.7953 - recall: 0.5801 - val_loss: 0.7784 - val_accuracy: 0.6963 - val_precision: 0.7662 - val_recall: 0.6194
# Epoch 5/40
# 802/802 [==============================] - 14s 18ms/step - loss: 0.6603 - accuracy: 0.7388 - precision: 0.8149 - recall: 0.6511 - val_loss: 0.6958 - val_accuracy: 0.7275 - val_precision: 0.7868 - val_recall: 0.6549
# Epoch 6/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.5691 - accuracy: 0.7767 - precision: 0.8343 - recall: 0.7160 - val_loss: 1.0378 - val_accuracy: 0.6648 - val_precision: 0.7172 - val_recall: 0.6108
# Epoch 7/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.7349 - accuracy: 0.7564 - precision: 0.8219 - recall: 0.6788 - val_loss: 0.6087 - val_accuracy: 0.7665 - val_precision: 0.8178 - val_recall: 0.7162
# Epoch 8/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.4641 - accuracy: 0.8216 - precision: 0.8581 - recall: 0.7809 - val_loss: 0.6742 - val_accuracy: 0.7573 - val_precision: 0.7883 - val_recall: 0.7206
# Epoch 9/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.4248 - accuracy: 0.8429 - precision: 0.8757 - recall: 0.8083 - val_loss: 0.6403 - val_accuracy: 0.7574 - val_precision: 0.8004 - val_recall: 0.7123
# Epoch 10/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.3768 - accuracy: 0.8628 - precision: 0.8877 - recall: 0.8344 - val_loss: 0.5884 - val_accuracy: 0.7932 - val_precision: 0.8180 - val_recall: 0.7699
# Epoch 11/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.3399 - accuracy: 0.8801 - precision: 0.8997 - recall: 0.8561 - val_loss: 0.5458 - val_accuracy: 0.7962 - val_precision: 0.8299 - val_recall: 0.7654
# Epoch 12/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.2995 - accuracy: 0.8904 - precision: 0.9069 - recall: 0.8735 - val_loss: 0.5505 - val_accuracy: 0.8012 - val_precision: 0.8254 - val_recall: 0.7753
# Epoch 13/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.2554 - accuracy: 0.9106 - precision: 0.9252 - recall: 0.8968 - val_loss: 0.5084 - val_accuracy: 0.8248 - val_precision: 0.8437 - val_recall: 0.8036
# Epoch 14/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.2284 - accuracy: 0.9199 - precision: 0.9307 - recall: 0.9075 - val_loss: 0.5316 - val_accuracy: 0.8164 - val_precision: 0.8373 - val_recall: 0.8021
# Epoch 15/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.2147 - accuracy: 0.9261 - precision: 0.9356 - recall: 0.9166 - val_loss: 0.4819 - val_accuracy: 0.8367 - val_precision: 0.8534 - val_recall: 0.8194
# Epoch 16/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.2139 - accuracy: 0.9253 - precision: 0.9343 - recall: 0.9164 - val_loss: 0.5802 - val_accuracy: 0.8100 - val_precision: 0.8268 - val_recall: 0.7940
# Epoch 17/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.2366 - accuracy: 0.9206 - precision: 0.9305 - recall: 0.9131 - val_loss: 0.5227 - val_accuracy: 0.8217 - val_precision: 0.8432 - val_recall: 0.8043
# Epoch 18/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.1851 - accuracy: 0.9374 - precision: 0.9450 - recall: 0.9303 - val_loss: 0.8652 - val_accuracy: 0.6848 - val_precision: 0.7382 - val_recall: 0.6410
# Epoch 19/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.3098 - accuracy: 0.8964 - precision: 0.9111 - recall: 0.8809 - val_loss: 0.5140 - val_accuracy: 0.8228 - val_precision: 0.8413 - val_recall: 0.8043
# Epoch 20/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.1960 - accuracy: 0.9317 - precision: 0.9398 - recall: 0.9230 - val_loss: 0.4887 - val_accuracy: 0.8451 - val_precision: 0.8573 - val_recall: 0.8350
# Epoch 21/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.1689 - accuracy: 0.9437 - precision: 0.9493 - recall: 0.9386 - val_loss: 0.4680 - val_accuracy: 0.8420 - val_precision: 0.8582 - val_recall: 0.8284
# Epoch 22/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.1823 - accuracy: 0.9433 - precision: 0.9504 - recall: 0.9361 - val_loss: 0.4721 - val_accuracy: 0.8556 - val_precision: 0.8670 - val_recall: 0.8469
# Epoch 23/40
# 802/802 [==============================] - 14s 18ms/step - loss: 0.1567 - accuracy: 0.9487 - precision: 0.9530 - recall: 0.9438 - val_loss: 0.5704 - val_accuracy: 0.8292 - val_precision: 0.8431 - val_recall: 0.8186
# Epoch 24/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.1438 - accuracy: 0.9537 - precision: 0.9584 - recall: 0.9492 - val_loss: 0.5465 - val_accuracy: 0.8436 - val_precision: 0.8536 - val_recall: 0.8348
# Epoch 25/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.1341 - accuracy: 0.9545 - precision: 0.9584 - recall: 0.9506 - val_loss: 0.6358 - val_accuracy: 0.8310 - val_precision: 0.8385 - val_recall: 0.8224
# Epoch 26/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.1368 - accuracy: 0.9573 - precision: 0.9607 - recall: 0.9538 - val_loss: 0.4873 - val_accuracy: 0.8548 - val_precision: 0.8684 - val_recall: 0.8440
# Epoch 27/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.1167 - accuracy: 0.9626 - precision: 0.9662 - recall: 0.9597 - val_loss: 0.4773 - val_accuracy: 0.8511 - val_precision: 0.8644 - val_recall: 0.8383
# Epoch 28/40
# 802/802 [==============================] - 14s 18ms/step - loss: 0.1162 - accuracy: 0.9620 - precision: 0.9660 - recall: 0.9591 - val_loss: 0.5775 - val_accuracy: 0.8466 - val_precision: 0.8542 - val_recall: 0.8399
# Epoch 29/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.1211 - accuracy: 0.9626 - precision: 0.9663 - recall: 0.9591 - val_loss: 0.5936 - val_accuracy: 0.8410 - val_precision: 0.8507 - val_recall: 0.8347
# Epoch 30/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.0903 - accuracy: 0.9709 - precision: 0.9737 - recall: 0.9688 - val_loss: 0.6320 - val_accuracy: 0.8504 - val_precision: 0.8573 - val_recall: 0.8450
# Epoch 31/40
# 802/802 [==============================] - 14s 17ms/step - loss: 0.1412 - accuracy: 0.9593 - precision: 0.9634 - recall: 0.9556 - val_loss: 0.6145 - val_accuracy: 0.8274 - val_precision: 0.8368 - val_recall: 0.8198
# 268/268 [==============================] - 2s 8ms/step - loss: 0.5905 - accuracy: 0.8396 - precision: 0.8489 - recall: 0.8304
#
# Test Acc. 83.96%
#               precision    recall  f1-score   support
#
#            0       0.84      0.79      0.81      1978
#            1       0.82      0.86      0.84      1957
#            2       0.89      0.87      0.88      2069
#            3       0.81      0.84      0.82      2011
#
#    micro avg       0.84      0.84      0.84      8015
#    macro avg       0.84      0.84      0.84      8015
# weighted avg       0.84      0.84      0.84      8015
#  samples avg       0.84      0.84      0.84      8015
#
# Confusion matrix
# [[1557  204   61  156]
#  [ 118 1674   54  111]
#  [  78   48 1805  138]
#  [  90  110  118 1693]]

# %% [markdown]
# <h3>Conclusion</h3>
#
# Hyperparam tuning on CNN+MLPNN: 72.74% accuracy </br>
# num_of_dense_layers: 3 </br>
# dense_layer[0]; unit:256 </br>
# dense_layer[1]; unit:384 </br>
# dense_layer[2]; unit:384 </br>
# num_of_conv_layers: 3 </br>
# conv_layer_filters[0]; unit:10 </br>
# conv_kernel[0]; unit:4 </br>
# conv_strides[0]; unit:3 </br>
# conv_layer_filters[1]; unit:30 </br>
# conv_kernel[1]; unit:5 </br>
# conv_strides[1]; unit:1 </br>
# conv_layer_filters[2]; unit:50 </br>
# conv_kernel[2]; unit:3 </br>
# conv_strides[2]; unit:1 </br>
# learningRate: 0.001 </br>
# isBatchNormalized: 0 </br>
# dropOutRate: 0.1 </br>
# startWithBatchNormalized: 1 </br>
# optimizer: Adam </br>
# activation: relu </br>
# </br>
#
# Hyperparam tuning on CNN + best MLPNN based model: 82.32% accuracy </br>
# num_of_dense_layers: 2 </br>
# dense_layer[0]; unit:512 </br>
# dense_layer[1]; unit:64 </br>
# num_of_conv_layers: 2 </br>
# conv_layer_filters[0]; unit:40 </br>
# conv_kernel[0]; unit:4 </br>
# conv_strides[0]; unit:1 </br>
# conv_layer_filters[1]; unit:30 </br>
# conv_kernel[1]; unit:2 </br>
# conv_strides[1]; unit:1 </br>
# learningRate: 0.001 </br>
# isBatchNormalized: False </br>
# dropOutRate: 0 </br>
# startWithBatchNormalized: True </br>
# optimizer: Adam </br>
# activation: relu </br>
#  </br>
#
# Manual tuning on CNN + MLPNN: 88.82% accuracy </br>
# num_of_dense_layers: 1 </br>
# dense_layer[0]; unit:512 </br>
# num_of_conv_layers: 3 </br>
# conv_layer_filters[0]; unit:100 </br>
# conv_kernel[0]; unit:3 </br>
# conv_strides[0]; unit:1 </br>
# conv_layer_filters[1]; unit:100 </br>
# conv_kernel[1]; unit:3 </br>
# conv_strides[1]; unit:1 </br>
# conv_layer_filters[2]; unit:100 </br>
# conv_kernel[2]; unit:3 </br>
# conv_strides[2]; unit:1 </br>
# learningRate: 0.1 </br>
# isBatchNormalized: False </br>
# dropOutRate: 0.5 </br>
# startWithBatchNormalized: True </br>
# optimizer: SGD </br>
# activation: relu </br>
