# %% [markdown]
# <h1>CNN model</h1>

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' #only show errors (hide INFO and WARNING)

import numpy as np
import pandas as pd
import random
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Flatten, concatenate, Input, Dropout, LSTM, Bidirectional,BatchNormalization,PReLU,ReLU,Reshape
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Sequential, Model, load_model
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
import keras_tuner as kt

random.seed(1234)   
np.random.seed(1234)

# %% [markdown]
# <h3>Helper functions to plot loss/accuracy, and build/train/test models.</h3>

# %%
def plot_loss_history(history):
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.xticks(range(0, len(history['loss'] + 1)))
  plt.plot(history['loss'], label="training", marker='o')
  plt.plot(history['val_loss'], label="validation", marker='o')
  plt.legend()
  plt.show()

def plot_accuracy_history(history):
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.xticks(range(0, len(history['accuracy'] + 1)))
  plt.plot(history['accuracy'], label="training", marker='o')
  plt.plot(history['val_accuracy'], label="validation", marker='o')
  plt.legend()
  plt.show()

# %%
def build_model(number_of_features, dense_layers_unit_array=[], learningRate=0.001,
                activation="relu", isBatchNormalized=False, dropOutRate=0,
                startWithBatchNormalized=False,optimizer="Adam",
                conv_layers_filters_array=[],conv_kernel_size_array=[],conv_strides_array=[]
               ):
    os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
    
    strategy = tf.distribute.MirroredStrategy(devices=None)
    print('Number of GPU/CPU: {}'.format(strategy.num_replicas_in_sync))
    
    print("num_of_dense_layers:",len(dense_layers_unit_array))
    
    for i, dense_layer_unit in enumerate(dense_layers_unit_array):       
        print("dense_layer["+str(i)+"]; unit:"+str(dense_layer_unit))      
        
        
    print("num_of_conv_layers:",len(conv_layers_filters_array))    
    for i, conv_layer_filters in enumerate(conv_layers_filters_array):       
        print("conv_layer_filters["+str(i)+"]; unit:"+str(conv_layer_filters))  
        print("conv_kernel["+str(i)+"]; unit:"+str(conv_kernel_size_array[i]))
        print("conv_strides["+str(i)+"]; unit:"+str(conv_strides_array[i]))
       
    print("learningRate:",learningRate)
    print("isBatchNormalized:",isBatchNormalized,"; dropOutRate:",dropOutRate)
    
    startWithBatchNormalized = startWithBatchNormalized or optimizer == "SGD"
    print("startWithBatchNormalized:",startWithBatchNormalized)
    print("optimizer:",optimizer,"; activation:",activation)
    
    tf.keras.backend.clear_session()
    tf.random.set_seed(1234)     
    np.random.seed(1234)
    random.seed(1234)
    
    with strategy.scope():   
        model = Sequential() 
        
        if startWithBatchNormalized:
            model.add(BatchNormalization())
        
        # Add Dense layers
        for i, conv_layer_filters in enumerate(conv_layers_filters_array):    
            model.add(tf.keras.layers.Conv1D(
            filters=conv_layer_filters,                
            kernel_size=conv_kernel_size_array[i],
            strides=conv_strides_array[i],
            padding='same',
            data_format='channels_last',
            name='conv_'+str(i),
            activation='relu'))
        
            model.add(tf.keras.layers.MaxPool1D(
                pool_size=2,
                name='pool_'+str(i))) 

        if len(conv_layers_filters_array) > 0:    
            model.add(Flatten()) 
        
        # Add Dense layers
        for i, dense_layer_unit in enumerate(dense_layers_unit_array):
            model.add(tf.keras.layers.Dense(
                units=dense_layer_unit,
                name='fc_'+str(i), 
                activation=activation))
            if isBatchNormalized:
                model.add(BatchNormalization())
            if dropOutRate > 0:
                model.add(Dropout(dropOutRate))

        model.add(Dense(4))
        model.add(Activation('softmax'))   

        model.build(input_shape=(None, number_of_features, 1))

        if optimizer=="Adam":
            opt = keras.optimizers.Adam(learning_rate=learningRate)
        elif optimizer=="SGD":
            opt = keras.optimizers.SGD(learning_rate=learningRate)
        else:
            opt = keras.optimizers.Adam(learning_rate=learningRate)    
        

        model.compile(optimizer=opt,
                      loss=['categorical_crossentropy'],
                      metrics=['accuracy', keras.metrics.Precision(), keras.metrics.Recall()])    
    
    return model

# %%
def train_and_test_model(train_dataset, validate_dataset, x_train,
                         save_to, epoch = 2,
                         dense_layers_unit_array=[],
                         patience=10, epoch_denominator=10.,
                         isConstantLearningRate=False, learningRate=0.001,
                         activation="relu", isBatchNormalized=False,dropOutRate=-1,
                         startWithBatchNormalized=False,optimizer="Adam",
                         conv_layers_filters_array=[],conv_kernel_size_array=[],conv_strides_array=[]
                        ):
    
    print("epoch:",epoch, "; epoch_denominator:",epoch_denominator) 
    print("patience:",patience,"; isConstantLearningRate:", isConstantLearningRate) 
    
    model = build_model(x_train.shape[1],
                        dense_layers_unit_array=dense_layers_unit_array, learningRate=learningRate,
                        activation=activation, isBatchNormalized=isBatchNormalized, dropOutRate=dropOutRate,
                        startWithBatchNormalized=startWithBatchNormalized,optimizer=optimizer,
                        conv_layers_filters_array=conv_layers_filters_array,
                        conv_kernel_size_array=conv_kernel_size_array,
                        conv_strides_array=conv_strides_array
                       )

    model.summary()
    tf.keras.utils.plot_model(model)  
    
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=patience)

    if isConstantLearningRate:  
        lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: learningRate)        
    else:  
        lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: learningRate * np.exp(-epoch / epoch_denominator))

    history = model.fit(train_dataset,
                        epochs=epoch,
                        validation_data=validate_dataset,
                        shuffle=True,
                        callbacks=[es,lr_schedule])

    history_data = pd.DataFrame(history.history)
    plot_loss_history(history_data)
    plot_accuracy_history(history_data)

    # test model
    test_results = model.evaluate(test_dataset)
    print('\nTest Acc. {:.2f}%'.format(test_results[1]*100))

    # show classification report
    y_predict = np.array(model.predict(test_dataset))
    y_predict = to_categorical(np.argmax(y_predict, axis=1), 4)
    print(classification_report(y_test, y_predict))
    
    print("Confusion matrix")
    print(confusion_matrix(y_test.values.argmax(axis=1), np.argmax(y_predict, axis=1)))

# %%
dataset = pd.read_csv('csv/out_gameemo.csv',  sep=',')

print('Shape of data: ', dataset.shape)
# Out:
# Shape of data:  (40071, 3739)

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

init_df = dataset.copy()

#HA_PV = high arousal, positive valence
#HA_NV = high arousal, negative valence
#LA_NV = low arousal, negative valence
#LA_PV = low arousal, positive valance
label_map = {1:"HA_PV", 2:"HA_NV", 3:"LA_NV", 4:"LA_PV"}

init_df["Label"] = init_df["Label"].map(label_map)


features = init_df.iloc[:, :-1]
label = init_df.iloc[:, -1:]

print('Shape of data: ', init_df.shape)
print('features.shape: ', features.shape)
print('label.shape: ', label.shape)

#######

y = label
X = features

X_train, X_validate, y_train, y_validate = train_test_split(X, y, train_size=0.6, random_state=48)

X_validate, X_test, y_validate, y_test = train_test_split(X_validate, y_validate, train_size=0.5, random_state=48)

X_train = np.array(X_train).reshape((X_train.shape[0],X_train.shape[1],1))
X_validate = np.array(X_validate).reshape((X_validate.shape[0],X_test.shape[1],1))
X_test = np.array(X_test).reshape((X_test.shape[0],X_test.shape[1],1))

y_train = pd.get_dummies(y_train)
y_validate = pd.get_dummies(y_validate)
y_test = pd.get_dummies(y_test)

print("y_train:")
print(y_train[:5])

#######
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
validate_dataset = tf.data.Dataset.from_tensor_slices((X_validate, y_validate))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))

options = tf.data.Options()
options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.DATA
train_dataset.with_options(options)
validate_dataset.with_options(options)
test_dataset.with_options(options)

batch_size = 30
train_dataset = train_dataset.batch(batch_size)
validate_dataset = validate_dataset.batch(batch_size)
test_dataset = test_dataset.batch(batch_size)
# Out:
# Shape of data:  (40071, 3739)
# features.shape:  (40071, 3738)
# label.shape:  (40071, 1)
# y_train:
#        Label_HA_NV  Label_HA_PV  Label_LA_NV  Label_LA_PV
# 13079            1            0            0            0
# 37831            1            0            0            0
# 23516            0            0            1            0
# 10630            0            1            0            0
# 36071            0            0            1            0

# %% [markdown]
# <h3>Perform hyperparam tuning using the CNN layer(s)</h3>

# %%
number_of_features = X_train.shape[1]

def model_tuner(hp):
    print("number_of_features:", number_of_features)
    
    # don't add any dense layer
    dense_layers_unit_array = []
    
    conv_layers_filters_array=[]
    conv_kernel_size_array=[]
    conv_strides_array=[]
    
    conv_layers_filters_array_size = hp.Int('conv_layers_filters_array_size', min_value=1, max_value=4, step=1)
    for i in range(conv_layers_filters_array_size):
        conv_layers_filters_array.append(hp.Int('conv_layers_filters_'+str(i), 
                                                min_value=10, max_value=70, step=10))
        conv_kernel_size_array.append(hp.Int('conv_kernel_'+str(i), 
                                                min_value=2, max_value=5, step=1))
        conv_strides_array.append(hp.Int('conv_stride_'+str(i), 
                                          min_value=1, max_value=3, step=1))
    
    model = build_model(number_of_features, 
                dense_layers_unit_array=dense_layers_unit_array, 
                learningRate=hp.Choice('learningRate', values=[0.01, 0.05, 0.1]),
                activation=hp.Choice('activation', values=["tanh", "relu"]), 
                isBatchNormalized=hp.Choice("isBatchNormalized", values=[True, False]), 
                dropOutRate=hp.Float('dropOutRate', min_value=0, max_value=0.7, step=0.1),
                startWithBatchNormalized=hp.Choice("startWithBatchNormalized", values=[True, False]),      
                optimizer=hp.Choice("optimizer", values=["Adam", "SGD"]),
                conv_layers_filters_array=conv_layers_filters_array,
                conv_kernel_size_array=conv_kernel_size_array,
                conv_strides_array=conv_strides_array     
                       )
    
    return model

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

epochs = 40
tuner = kt.Hyperband(model_tuner,
                     objective='val_accuracy',
                     max_epochs=epochs,
                     factor=3,
                     directory='.',
                     seed=1234,
                     project_name='eeg')


stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)


tuner.search(train_dataset, 
             epochs=epochs, 
             validation_data=validate_dataset,
             shuffle=True,
             callbacks=[stop_early])

best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print("#### Hypertuning results:")

print("learningRate:",best_hps.get('learningRate'))
print("isBatchNormalized:",best_hps.get('isBatchNormalized'))
print("dropOutRate:",best_hps.get('dropOutRate'))
print("conv_layers_filters_array_size:",best_hps.get('conv_layers_filters_array_size'))

try:
    print("conv_layers_filters_0:",best_hps.get('conv_layers_filters_0'))
    print("conv_kernel_0:",best_hps.get('conv_kernel_0'))
    print("conv_stride_0:",best_hps.get('conv_stride_0'))
except:
    print("no conv layer 0")
    
try:
    print("conv_layers_filters_1:",best_hps.get('conv_layers_filters_1'))
    print("conv_kernel_1:",best_hps.get('conv_kernel_1'))
    print("conv_stride_1:",best_hps.get('conv_stride_1'))
except:
    print("no conv layer 1")
    
try:
    print("conv_layers_filters_2:",best_hps.get('conv_layers_filters_2'))
    print("conv_kernel_2:",best_hps.get('conv_kernel_2'))
    print("conv_stride_2:",best_hps.get('conv_stride_2'))    
except:
    print("no conv layer 2")
    
try:
    print("conv_layers_filters_0:",best_hps.get('conv_layers_filters_3'))
    print("conv_kernel_3:",best_hps.get('conv_kernel_3'))
    print("conv_stride_3:",best_hps.get('conv_stride_3'))    
except:
    print("no conv layer 3")    

print("dropOutRate:",best_hps.get('dropOutRate'))

print("#########################################")
print("")


model = tuner.hypermodel.build(best_hps)
history = model.fit(train_dataset, 
             epochs=epochs, 
             validation_data=validate_dataset,
             shuffle=True,
             callbacks=[stop_early])

history_data = pd.DataFrame(history.history)
plot_loss_history(history_data)
plot_accuracy_history(history_data)

# test model
test_results = model.evaluate(test_dataset)
print('\nTest Acc. {:.2f}%'.format(test_results[1]*100))

# show classification report
y_predict = np.array(model.predict(test_dataset))
y_predict = to_categorical(np.argmax(y_predict, axis=1), 4)
print(classification_report(y_test, y_predict))
# Out:
# Trial 90 Complete [00h 02m 58s]
# val_accuracy: 0.2529323697090149
#
# Best val_accuracy So Far: 0.741951584815979
# Total elapsed time: 01h 47m 33s
# INFO:tensorflow:Oracle triggered exit
# #### Hypertuning results:
# learningRate: 0.05
# isBatchNormalized: 1
# dropOutRate: 0.1
# conv_layers_filters_array_size: 2
# conv_layers_filters_0: 60
# conv_kernel_0: 4
# conv_stride_0: 1
# conv_layers_filters_1: 50
# conv_kernel_1: 3
# conv_stride_1: 2
# conv_layers_filters_2: 70
# conv_kernel_2: 2
# conv_stride_2: 1
# conv_layers_filters_0: 10
# conv_kernel_3: 3
# conv_stride_3: 3
# dropOutRate: 0.1
# #########################################
#
# number_of_features: 3738
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of GPU/CPU: 2
# num_of_dense_layers: 0
# num_of_conv_layers: 2
# conv_layer_filters[0]; unit:60
# conv_kernel[0]; unit:4
# conv_strides[0]; unit:1
# conv_layer_filters[1]; unit:50
# conv_kernel[1]; unit:3
# conv_strides[1]; unit:2
# learningRate: 0.05
# isBatchNormalized: 1 ; dropOutRate: 0.1
# startWithBatchNormalized: True
# optimizer: SGD ; activation: tanh
# Epoch 1/40
# 802/802 [==============================] - 14s 12ms/step - loss: 1.3646 - accuracy: 0.3447 - precision: 0.4907 - recall: 0.0250 - val_loss: 1.3159 - val_accuracy: 0.3429 - val_precision: 0.6119 - val_recall: 0.0618
# Epoch 2/40
# 802/802 [==============================] - 8s 10ms/step - loss: 1.1863 - accuracy: 0.5006 - precision: 0.6921 - recall: 0.1627 - val_loss: 1.1550 - val_accuracy: 0.5253 - val_precision: 0.7298 - val_recall: 0.1942
# Epoch 3/40
# 802/802 [==============================] - 8s 10ms/step - loss: 1.0256 - accuracy: 0.5910 - precision: 0.7425 - recall: 0.3358 - val_loss: 1.0518 - val_accuracy: 0.5752 - val_precision: 0.7324 - val_recall: 0.3252
# Epoch 4/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.9081 - accuracy: 0.6384 - precision: 0.7662 - recall: 0.4548 - val_loss: 0.9612 - val_accuracy: 0.6210 - val_precision: 0.7512 - val_recall: 0.4302
# Epoch 5/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8173 - accuracy: 0.6856 - precision: 0.7871 - recall: 0.5425 - val_loss: 0.9365 - val_accuracy: 0.6283 - val_precision: 0.7451 - val_recall: 0.4717
# Epoch 6/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7538 - accuracy: 0.7093 - precision: 0.7934 - recall: 0.5896 - val_loss: 0.9094 - val_accuracy: 0.6434 - val_precision: 0.7490 - val_recall: 0.5176
# Epoch 7/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6937 - accuracy: 0.7331 - precision: 0.8093 - recall: 0.6329 - val_loss: 0.9255 - val_accuracy: 0.6378 - val_precision: 0.7139 - val_recall: 0.5493
# Epoch 8/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6515 - accuracy: 0.7521 - precision: 0.8172 - recall: 0.6655 - val_loss: 0.8904 - val_accuracy: 0.6539 - val_precision: 0.7178 - val_recall: 0.5811
# Epoch 9/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6143 - accuracy: 0.7678 - precision: 0.8231 - recall: 0.6928 - val_loss: 0.9267 - val_accuracy: 0.6601 - val_precision: 0.7105 - val_recall: 0.5852
# Epoch 10/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5807 - accuracy: 0.7822 - precision: 0.8346 - recall: 0.7182 - val_loss: 1.0145 - val_accuracy: 0.6259 - val_precision: 0.6671 - val_recall: 0.5850
# Epoch 11/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5506 - accuracy: 0.7972 - precision: 0.8407 - recall: 0.7394 - val_loss: 0.8202 - val_accuracy: 0.7008 - val_precision: 0.7555 - val_recall: 0.6285
# Epoch 12/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5038 - accuracy: 0.8103 - precision: 0.8528 - recall: 0.7624 - val_loss: 0.8218 - val_accuracy: 0.7066 - val_precision: 0.7551 - val_recall: 0.6430
# Epoch 13/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4984 - accuracy: 0.8146 - precision: 0.8550 - recall: 0.7683 - val_loss: 0.8000 - val_accuracy: 0.7116 - val_precision: 0.7586 - val_recall: 0.6487
# Epoch 14/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4782 - accuracy: 0.8231 - precision: 0.8592 - recall: 0.7799 - val_loss: 0.7977 - val_accuracy: 0.7240 - val_precision: 0.7696 - val_recall: 0.6647
# Epoch 15/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4449 - accuracy: 0.8345 - precision: 0.8677 - recall: 0.7941 - val_loss: 0.8320 - val_accuracy: 0.7128 - val_precision: 0.7587 - val_recall: 0.6552
# Epoch 16/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4455 - accuracy: 0.8365 - precision: 0.8700 - recall: 0.8001 - val_loss: 0.8815 - val_accuracy: 0.7044 - val_precision: 0.7381 - val_recall: 0.6691
# Epoch 17/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4312 - accuracy: 0.8425 - precision: 0.8695 - recall: 0.8078 - val_loss: 0.7896 - val_accuracy: 0.7347 - val_precision: 0.7743 - val_recall: 0.6869
# Epoch 18/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4189 - accuracy: 0.8481 - precision: 0.8745 - recall: 0.8132 - val_loss: 0.9247 - val_accuracy: 0.6983 - val_precision: 0.7295 - val_recall: 0.6670
# Epoch 19/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3722 - accuracy: 0.8650 - precision: 0.8886 - recall: 0.8371 - val_loss: 0.9189 - val_accuracy: 0.7071 - val_precision: 0.7397 - val_recall: 0.6640
# Epoch 20/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3861 - accuracy: 0.8626 - precision: 0.8870 - recall: 0.8320 - val_loss: 0.8907 - val_accuracy: 0.7214 - val_precision: 0.7527 - val_recall: 0.6862
# Epoch 21/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3547 - accuracy: 0.8697 - precision: 0.8917 - recall: 0.8468 - val_loss: 0.8313 - val_accuracy: 0.7454 - val_precision: 0.7717 - val_recall: 0.7094
# Epoch 22/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3449 - accuracy: 0.8719 - precision: 0.8928 - recall: 0.8496 - val_loss: 0.9556 - val_accuracy: 0.7066 - val_precision: 0.7301 - val_recall: 0.6768
# Epoch 23/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3341 - accuracy: 0.8744 - precision: 0.8948 - recall: 0.8535 - val_loss: 0.8730 - val_accuracy: 0.7290 - val_precision: 0.7568 - val_recall: 0.6978
# Epoch 24/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3255 - accuracy: 0.8812 - precision: 0.9009 - recall: 0.8630 - val_loss: 0.8786 - val_accuracy: 0.7398 - val_precision: 0.7634 - val_recall: 0.7118
# Epoch 25/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3558 - accuracy: 0.8717 - precision: 0.8892 - recall: 0.8489 - val_loss: 0.8414 - val_accuracy: 0.7467 - val_precision: 0.7696 - val_recall: 0.7165
# Epoch 26/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3241 - accuracy: 0.8818 - precision: 0.9006 - recall: 0.8623 - val_loss: 0.9136 - val_accuracy: 0.7204 - val_precision: 0.7451 - val_recall: 0.6959
# Epoch 27/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3138 - accuracy: 0.8828 - precision: 0.9023 - recall: 0.8660 - val_loss: 0.8966 - val_accuracy: 0.7408 - val_precision: 0.7607 - val_recall: 0.7126
# 268/268 [==============================] - 2s 6ms/step - loss: 0.8596 - accuracy: 0.7460 - precision: 0.7731 - recall: 0.7238
#
# Test Acc. 74.60%
#               precision    recall  f1-score   support
#
#            0       0.77      0.68      0.72      1978
#            1       0.80      0.73      0.76      1957
#            2       0.77      0.80      0.79      2069
#            3       0.66      0.77      0.71      2011
#
#    micro avg       0.75      0.75      0.75      8015
#    macro avg       0.75      0.75      0.75      8015
# weighted avg       0.75      0.75      0.75      8015
#  samples avg       0.75      0.75      0.75      8015

# %% [markdown]
# <h3>Best CNN model by hyperparams tuning</h3>
#
# Conv layer 1: 60 filters, 4 kernels, 1 stride
# <br>
# Conv layer 2: 50 filters, 3 kernels, 2 stride
# <br>
#
# learning rate: 0.05<br>
# isBatchNormalized: true<br>
# dropOutRate: 0.1<br>
# startWithBatchNormalized: True<br>
# optimizer: SGD<br>
# activation: tanh<br>
# <br>
# Test accuracy: 74.60%, loss: 0.8596

# %% [markdown]
# <h1>Random runs to get a feel of the hyperparameters</h1>

# %%
train_and_test_model(train_dataset, validate_dataset, X_train, save_to= './', epoch = 40, 
                     dense_layers_unit_array=[], learningRate=0.1,
                     startWithBatchNormalized=True, optimizer="SGD",dropOutRate=0.5,
                     activation="relu",
                     conv_layers_filters_array=[50],
                     conv_kernel_size_array=[3],
                     conv_strides_array=[1]
                    )
# Out:
# epoch: 40 ; epoch_denominator: 10.0
# patience: 10 ; isConstantLearningRate: False
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of GPU/CPU: 2
# num_of_dense_layers: 0
# num_of_conv_layers: 1
# conv_layer_filters[0]; unit:50
# conv_kernel[0]; unit:3
# conv_strides[0]; unit:1
# learningRate: 0.1
# isBatchNormalized: False ; dropOutRate: 0.5
# startWithBatchNormalized: True
# optimizer: SGD ; activation: relu
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 3738, 1)           4
# _________________________________________________________________
# conv_0 (Conv1D)              (None, 3738, 50)          200
# _________________________________________________________________
# pool_0 (MaxPooling1D)        (None, 1869, 50)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 93450)             0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 373804
# _________________________________________________________________
# activation (Activation)      (None, 4)                 0
# =================================================================
# Total params: 374,008
# Trainable params: 374,006
# Non-trainable params: 2
# _________________________________________________________________
# Epoch 1/40
# 802/802 [==============================] - 13s 11ms/step - loss: 1.4965 - accuracy: 0.2894 - precision: 0.4290 - recall: 0.0159 - val_loss: 1.3472 - val_accuracy: 0.3535 - val_precision: 0.5409 - val_recall: 0.0347
# Epoch 2/40
# 802/802 [==============================] - 7s 9ms/step - loss: 1.3034 - accuracy: 0.4094 - precision: 0.5642 - recall: 0.0690 - val_loss: 1.3601 - val_accuracy: 0.3602 - val_precision: 0.5787 - val_recall: 0.0564
# Epoch 3/40
# 802/802 [==============================] - 8s 10ms/step - loss: 1.2674 - accuracy: 0.4502 - precision: 0.6175 - recall: 0.1094 - val_loss: 1.3697 - val_accuracy: 0.3410 - val_precision: 0.5746 - val_recall: 0.0706
# Epoch 4/40
# 802/802 [==============================] - 8s 10ms/step - loss: 1.2336 - accuracy: 0.4749 - precision: 0.6486 - recall: 0.1430 - val_loss: 1.3270 - val_accuracy: 0.4089 - val_precision: 0.6038 - val_recall: 0.0679
# Epoch 5/40
# 802/802 [==============================] - 8s 10ms/step - loss: 1.2028 - accuracy: 0.5026 - precision: 0.6738 - recall: 0.1762 - val_loss: 1.3157 - val_accuracy: 0.4110 - val_precision: 0.6196 - val_recall: 0.0772
# Epoch 6/40
# 802/802 [==============================] - 8s 10ms/step - loss: 1.1698 - accuracy: 0.5210 - precision: 0.6942 - recall: 0.2136 - val_loss: 1.2967 - val_accuracy: 0.4350 - val_precision: 0.6506 - val_recall: 0.1008
# Epoch 7/40
# 802/802 [==============================] - 7s 9ms/step - loss: 1.1401 - accuracy: 0.5390 - precision: 0.7059 - recall: 0.2440 - val_loss: 1.3075 - val_accuracy: 0.4119 - val_precision: 0.6477 - val_recall: 0.0936
# Epoch 8/40
# 802/802 [==============================] - 8s 9ms/step - loss: 1.1156 - accuracy: 0.5526 - precision: 0.7153 - recall: 0.2673 - val_loss: 1.2732 - val_accuracy: 0.4725 - val_precision: 0.6665 - val_recall: 0.1391
# Epoch 9/40
# 802/802 [==============================] - 8s 10ms/step - loss: 1.0924 - accuracy: 0.5662 - precision: 0.7186 - recall: 0.2920 - val_loss: 1.2848 - val_accuracy: 0.4823 - val_precision: 0.6713 - val_recall: 0.1705
# Epoch 10/40
# 802/802 [==============================] - 8s 10ms/step - loss: 1.0712 - accuracy: 0.5760 - precision: 0.7293 - recall: 0.3104 - val_loss: 1.2229 - val_accuracy: 0.5031 - val_precision: 0.7017 - val_recall: 0.1832
# Epoch 11/40
# 802/802 [==============================] - 8s 10ms/step - loss: 1.0495 - accuracy: 0.5854 - precision: 0.7359 - recall: 0.3311 - val_loss: 1.2863 - val_accuracy: 0.4723 - val_precision: 0.6593 - val_recall: 0.2321
# Epoch 12/40
# 802/802 [==============================] - 8s 10ms/step - loss: 1.0308 - accuracy: 0.5966 - precision: 0.7403 - recall: 0.3463 - val_loss: 1.2514 - val_accuracy: 0.4842 - val_precision: 0.6701 - val_recall: 0.2492
# Epoch 13/40
# 802/802 [==============================] - 7s 9ms/step - loss: 1.0108 - accuracy: 0.6070 - precision: 0.7490 - recall: 0.3618 - val_loss: 1.2244 - val_accuracy: 0.4946 - val_precision: 0.6889 - val_recall: 0.2578
# Epoch 14/40
# 802/802 [==============================] - 8s 9ms/step - loss: 0.9955 - accuracy: 0.6138 - precision: 0.7529 - recall: 0.3761 - val_loss: 1.2080 - val_accuracy: 0.4960 - val_precision: 0.6703 - val_recall: 0.2775
# Epoch 15/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.9756 - accuracy: 0.6208 - precision: 0.7537 - recall: 0.3888 - val_loss: 1.1890 - val_accuracy: 0.5100 - val_precision: 0.6885 - val_recall: 0.2871
# Epoch 16/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.9566 - accuracy: 0.6288 - precision: 0.7619 - recall: 0.4055 - val_loss: 1.2362 - val_accuracy: 0.4920 - val_precision: 0.6326 - val_recall: 0.3167
# Epoch 17/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.9402 - accuracy: 0.6349 - precision: 0.7673 - recall: 0.4215 - val_loss: 1.2052 - val_accuracy: 0.5105 - val_precision: 0.6614 - val_recall: 0.3193
# Epoch 18/40
# 802/802 [==============================] - 7s 9ms/step - loss: 0.9251 - accuracy: 0.6413 - precision: 0.7717 - recall: 0.4310 - val_loss: 1.2193 - val_accuracy: 0.5130 - val_precision: 0.6554 - val_recall: 0.3299
# Epoch 19/40
# 802/802 [==============================] - 8s 9ms/step - loss: 0.9098 - accuracy: 0.6489 - precision: 0.7774 - recall: 0.4451 - val_loss: 1.1992 - val_accuracy: 0.5253 - val_precision: 0.6700 - val_recall: 0.3357
# Epoch 20/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8952 - accuracy: 0.6547 - precision: 0.7795 - recall: 0.4560 - val_loss: 1.1565 - val_accuracy: 0.5408 - val_precision: 0.6935 - val_recall: 0.3425
# Epoch 21/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8833 - accuracy: 0.6603 - precision: 0.7820 - recall: 0.4644 - val_loss: 1.1614 - val_accuracy: 0.5414 - val_precision: 0.6915 - val_recall: 0.3505
# Epoch 22/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8726 - accuracy: 0.6660 - precision: 0.7848 - recall: 0.4738 - val_loss: 1.1260 - val_accuracy: 0.5550 - val_precision: 0.7094 - val_recall: 0.3545
# Epoch 23/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8587 - accuracy: 0.6695 - precision: 0.7886 - recall: 0.4850 - val_loss: 1.1201 - val_accuracy: 0.5575 - val_precision: 0.7093 - val_recall: 0.3611
# Epoch 24/40
# 802/802 [==============================] - 7s 9ms/step - loss: 0.8479 - accuracy: 0.6745 - precision: 0.7903 - recall: 0.4927 - val_loss: 1.1030 - val_accuracy: 0.5640 - val_precision: 0.7175 - val_recall: 0.3664
# Epoch 25/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8372 - accuracy: 0.6785 - precision: 0.7940 - recall: 0.5011 - val_loss: 1.0868 - val_accuracy: 0.5671 - val_precision: 0.7244 - val_recall: 0.3712
# Epoch 26/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8267 - accuracy: 0.6844 - precision: 0.7972 - recall: 0.5096 - val_loss: 1.0764 - val_accuracy: 0.5724 - val_precision: 0.7291 - val_recall: 0.3772
# Epoch 27/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8174 - accuracy: 0.6862 - precision: 0.7980 - recall: 0.5179 - val_loss: 1.0660 - val_accuracy: 0.5775 - val_precision: 0.7335 - val_recall: 0.3823
# Epoch 28/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8080 - accuracy: 0.6905 - precision: 0.7996 - recall: 0.5255 - val_loss: 1.0555 - val_accuracy: 0.5829 - val_precision: 0.7352 - val_recall: 0.3897
# Epoch 29/40
# 802/802 [==============================] - 8s 9ms/step - loss: 0.7992 - accuracy: 0.6955 - precision: 0.8026 - recall: 0.5336 - val_loss: 1.0449 - val_accuracy: 0.5868 - val_precision: 0.7386 - val_recall: 0.3949
# Epoch 30/40
# 802/802 [==============================] - 7s 9ms/step - loss: 0.7908 - accuracy: 0.6988 - precision: 0.8040 - recall: 0.5392 - val_loss: 1.0348 - val_accuracy: 0.5932 - val_precision: 0.7433 - val_recall: 0.3999
# Epoch 31/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7831 - accuracy: 0.7036 - precision: 0.8081 - recall: 0.5467 - val_loss: 1.0262 - val_accuracy: 0.5982 - val_precision: 0.7449 - val_recall: 0.4052
# Epoch 32/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7758 - accuracy: 0.7072 - precision: 0.8098 - recall: 0.5515 - val_loss: 1.0178 - val_accuracy: 0.6016 - val_precision: 0.7497 - val_recall: 0.4088
# Epoch 33/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7692 - accuracy: 0.7097 - precision: 0.8118 - recall: 0.5579 - val_loss: 1.0107 - val_accuracy: 0.6062 - val_precision: 0.7538 - val_recall: 0.4142
# Epoch 34/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7632 - accuracy: 0.7125 - precision: 0.8139 - recall: 0.5635 - val_loss: 1.0043 - val_accuracy: 0.6111 - val_precision: 0.7549 - val_recall: 0.4163
# Epoch 35/40
# 802/802 [==============================] - 7s 9ms/step - loss: 0.7572 - accuracy: 0.7155 - precision: 0.8159 - recall: 0.5685 - val_loss: 0.9980 - val_accuracy: 0.6152 - val_precision: 0.7601 - val_recall: 0.4203
# Epoch 36/40
# 802/802 [==============================] - 8s 9ms/step - loss: 0.7518 - accuracy: 0.7176 - precision: 0.8166 - recall: 0.5724 - val_loss: 0.9922 - val_accuracy: 0.6190 - val_precision: 0.7611 - val_recall: 0.4214
# Epoch 37/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7466 - accuracy: 0.7201 - precision: 0.8178 - recall: 0.5762 - val_loss: 0.9870 - val_accuracy: 0.6238 - val_precision: 0.7625 - val_recall: 0.4248
# Epoch 38/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7418 - accuracy: 0.7211 - precision: 0.8197 - recall: 0.5796 - val_loss: 0.9820 - val_accuracy: 0.6277 - val_precision: 0.7672 - val_recall: 0.4280
# Epoch 39/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7373 - accuracy: 0.7221 - precision: 0.8204 - recall: 0.5824 - val_loss: 0.9780 - val_accuracy: 0.6325 - val_precision: 0.7703 - val_recall: 0.4317
# Epoch 40/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7332 - accuracy: 0.7231 - precision: 0.8215 - recall: 0.5862 - val_loss: 0.9746 - val_accuracy: 0.6356 - val_precision: 0.7732 - val_recall: 0.4356
# 268/268 [==============================] - 2s 5ms/step - loss: 0.9638 - accuracy: 0.6513 - precision: 0.7764 - recall: 0.4449
#
# Test Acc. 65.13%
#               precision    recall  f1-score   support
#
#            0       0.63      0.67      0.65      1978
#            1       0.75      0.56      0.64      1957
#            2       0.64      0.77      0.70      2069
#            3       0.61      0.60      0.60      2011
#
#    micro avg       0.65      0.65      0.65      8015
#    macro avg       0.66      0.65      0.65      8015
# weighted avg       0.66      0.65      0.65      8015
#  samples avg       0.65      0.65      0.65      8015
#
# Confusion matrix
# [[1331  170  226  251]
#  [ 327 1095  268  267]
#  [ 158   80 1595  236]
#  [ 282  110  420 1199]]

# %%
train_and_test_model(train_dataset, validate_dataset, X_train, save_to= './', epoch = 40, 
                     dense_layers_unit_array=[], learningRate=0.1,
                     startWithBatchNormalized=True, optimizer="SGD",dropOutRate=0.5,
                     activation="relu",
                     conv_layers_filters_array=[50,50],
                     conv_kernel_size_array=[3,3],
                     conv_strides_array=[1,1]
                    )
# Out:
# epoch: 40 ; epoch_denominator: 10.0
# patience: 10 ; isConstantLearningRate: False
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of GPU/CPU: 2
# num_of_dense_layers: 0
# num_of_conv_layers: 2
# conv_layer_filters[0]; unit:50
# conv_kernel[0]; unit:3
# conv_strides[0]; unit:1
# conv_layer_filters[1]; unit:50
# conv_kernel[1]; unit:3
# conv_strides[1]; unit:1
# learningRate: 0.1
# isBatchNormalized: False ; dropOutRate: 0.5
# startWithBatchNormalized: True
# optimizer: SGD ; activation: relu
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 3738, 1)           4
# _________________________________________________________________
# conv_0 (Conv1D)              (None, 3738, 50)          200
# _________________________________________________________________
# pool_0 (MaxPooling1D)        (None, 1869, 50)          0
# _________________________________________________________________
# conv_1 (Conv1D)              (None, 1869, 50)          7550
# _________________________________________________________________
# pool_1 (MaxPooling1D)        (None, 934, 50)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 46700)             0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 186804
# _________________________________________________________________
# activation (Activation)      (None, 4)                 0
# =================================================================
# Total params: 194,558
# Trainable params: 194,556
# Non-trainable params: 2
# _________________________________________________________________
# Epoch 1/40
# 802/802 [==============================] - 13s 13ms/step - loss: 1.3850 - accuracy: 0.3213 - precision: 0.4376 - recall: 0.0191 - val_loss: 1.2786 - val_accuracy: 0.4522 - val_precision: 0.6046 - val_recall: 0.0595
# Epoch 2/40
# 802/802 [==============================] - 8s 10ms/step - loss: 1.1666 - accuracy: 0.5073 - precision: 0.6805 - recall: 0.1995 - val_loss: 1.2373 - val_accuracy: 0.4683 - val_precision: 0.5625 - val_recall: 0.3171
# Epoch 3/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.9605 - accuracy: 0.6157 - precision: 0.7411 - recall: 0.4250 - val_loss: 1.2763 - val_accuracy: 0.4183 - val_precision: 0.6380 - val_recall: 0.0732
# Epoch 4/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.9956 - accuracy: 0.5967 - precision: 0.7269 - recall: 0.3903 - val_loss: 0.9958 - val_accuracy: 0.5968 - val_precision: 0.7036 - val_recall: 0.4381
# Epoch 5/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8104 - accuracy: 0.6810 - precision: 0.7676 - recall: 0.5535 - val_loss: 2.7554 - val_accuracy: 0.2984 - val_precision: 0.3025 - val_recall: 0.2790
# Epoch 6/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8327 - accuracy: 0.6827 - precision: 0.7700 - recall: 0.5580 - val_loss: 0.8687 - val_accuracy: 0.6628 - val_precision: 0.7540 - val_recall: 0.5346
# Epoch 7/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6723 - accuracy: 0.7437 - precision: 0.8109 - recall: 0.6493 - val_loss: 0.8715 - val_accuracy: 0.6700 - val_precision: 0.7422 - val_recall: 0.5635
# Epoch 8/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6116 - accuracy: 0.7662 - precision: 0.8232 - recall: 0.6919 - val_loss: 0.8675 - val_accuracy: 0.6826 - val_precision: 0.7445 - val_recall: 0.6009
# Epoch 9/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5606 - accuracy: 0.7871 - precision: 0.8382 - recall: 0.7234 - val_loss: 0.8638 - val_accuracy: 0.6799 - val_precision: 0.7373 - val_recall: 0.6083
# Epoch 10/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5209 - accuracy: 0.8033 - precision: 0.8497 - recall: 0.7445 - val_loss: 0.8549 - val_accuracy: 0.6992 - val_precision: 0.7508 - val_recall: 0.6389
# Epoch 11/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4775 - accuracy: 0.8189 - precision: 0.8592 - recall: 0.7714 - val_loss: 0.8681 - val_accuracy: 0.6967 - val_precision: 0.7401 - val_recall: 0.6411
# Epoch 12/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4443 - accuracy: 0.8300 - precision: 0.8662 - recall: 0.7904 - val_loss: 0.8368 - val_accuracy: 0.7106 - val_precision: 0.7542 - val_recall: 0.6569
# Epoch 13/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4046 - accuracy: 0.8474 - precision: 0.8795 - recall: 0.8112 - val_loss: 0.8944 - val_accuracy: 0.7009 - val_precision: 0.7355 - val_recall: 0.6562
# Epoch 14/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3784 - accuracy: 0.8579 - precision: 0.8866 - recall: 0.8270 - val_loss: 0.8328 - val_accuracy: 0.7240 - val_precision: 0.7628 - val_recall: 0.6846
# Epoch 15/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3399 - accuracy: 0.8745 - precision: 0.9006 - recall: 0.8463 - val_loss: 0.8483 - val_accuracy: 0.7252 - val_precision: 0.7584 - val_recall: 0.6895
# Epoch 16/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3219 - accuracy: 0.8778 - precision: 0.9013 - recall: 0.8543 - val_loss: 0.8374 - val_accuracy: 0.7305 - val_precision: 0.7634 - val_recall: 0.6940
# Epoch 17/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2966 - accuracy: 0.8896 - precision: 0.9117 - recall: 0.8681 - val_loss: 0.8821 - val_accuracy: 0.7305 - val_precision: 0.7569 - val_recall: 0.6993
# Epoch 18/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2825 - accuracy: 0.8957 - precision: 0.9149 - recall: 0.8743 - val_loss: 0.8745 - val_accuracy: 0.7352 - val_precision: 0.7604 - val_recall: 0.7066
# Epoch 19/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2624 - accuracy: 0.9030 - precision: 0.9223 - recall: 0.8836 - val_loss: 0.8778 - val_accuracy: 0.7365 - val_precision: 0.7624 - val_recall: 0.7085
# Epoch 20/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2436 - accuracy: 0.9093 - precision: 0.9247 - recall: 0.8911 - val_loss: 0.8946 - val_accuracy: 0.7423 - val_precision: 0.7635 - val_recall: 0.7182
# Epoch 21/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2273 - accuracy: 0.9161 - precision: 0.9321 - recall: 0.8995 - val_loss: 0.9048 - val_accuracy: 0.7412 - val_precision: 0.7661 - val_recall: 0.7190
# Epoch 22/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2077 - accuracy: 0.9259 - precision: 0.9399 - recall: 0.9108 - val_loss: 0.8998 - val_accuracy: 0.7472 - val_precision: 0.7657 - val_recall: 0.7252
# Epoch 23/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1911 - accuracy: 0.9326 - precision: 0.9446 - recall: 0.9179 - val_loss: 0.9149 - val_accuracy: 0.7503 - val_precision: 0.7675 - val_recall: 0.7302
# Epoch 24/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1796 - accuracy: 0.9362 - precision: 0.9488 - recall: 0.9242 - val_loss: 0.9338 - val_accuracy: 0.7547 - val_precision: 0.7716 - val_recall: 0.7362
# Epoch 00024: early stopping
# 268/268 [==============================] - 2s 6ms/step - loss: 0.9666 - accuracy: 0.7521 - precision: 0.7667 - recall: 0.7347
#
# Test Acc. 75.21%
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73      1978
#            1       0.81      0.71      0.76      1957
#            2       0.79      0.81      0.80      2069
#            3       0.69      0.76      0.72      2011
#
#    micro avg       0.75      0.75      0.75      8015
#    macro avg       0.76      0.75      0.75      8015
# weighted avg       0.76      0.75      0.75      8015
#  samples avg       0.75      0.75      0.75      8015
#
# Confusion matrix
# [[1446  178  119  235]
#  [ 244 1394  106  213]
#  [ 104   58 1667  240]
#  [ 180   96  214 1521]]

# %%
train_and_test_model(train_dataset, validate_dataset, X_train, save_to= './', epoch = 40, 
                     dense_layers_unit_array=[], learningRate=0.1,
                     startWithBatchNormalized=True, optimizer="SGD",dropOutRate=0.5,
                     activation="relu",
                     conv_layers_filters_array=[50,50,50],
                     conv_kernel_size_array=[3,3,3],
                     conv_strides_array=[1,1,1]
                    )
# Out:
# epoch: 40 ; epoch_denominator: 10.0
# patience: 10 ; isConstantLearningRate: False
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of GPU/CPU: 2
# num_of_dense_layers: 0
# num_of_conv_layers: 3
# conv_layer_filters[0]; unit:50
# conv_kernel[0]; unit:3
# conv_strides[0]; unit:1
# conv_layer_filters[1]; unit:50
# conv_kernel[1]; unit:3
# conv_strides[1]; unit:1
# conv_layer_filters[2]; unit:50
# conv_kernel[2]; unit:3
# conv_strides[2]; unit:1
# learningRate: 0.1
# isBatchNormalized: False ; dropOutRate: 0.5
# startWithBatchNormalized: True
# optimizer: SGD ; activation: relu
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 3738, 1)           4
# _________________________________________________________________
# conv_0 (Conv1D)              (None, 3738, 50)          200
# _________________________________________________________________
# pool_0 (MaxPooling1D)        (None, 1869, 50)          0
# _________________________________________________________________
# conv_1 (Conv1D)              (None, 1869, 50)          7550
# _________________________________________________________________
# pool_1 (MaxPooling1D)        (None, 934, 50)           0
# _________________________________________________________________
# conv_2 (Conv1D)              (None, 934, 50)           7550
# _________________________________________________________________
# pool_2 (MaxPooling1D)        (None, 467, 50)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 23350)             0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 93404
# _________________________________________________________________
# activation (Activation)      (None, 4)                 0
# =================================================================
# Total params: 108,708
# Trainable params: 108,706
# Non-trainable params: 2
# _________________________________________________________________
# Epoch 1/40
# 802/802 [==============================] - 14s 13ms/step - loss: 1.3666 - accuracy: 0.3261 - precision: 0.4878 - recall: 0.0220 - val_loss: 1.2481 - val_accuracy: 0.4340 - val_precision: 0.6535 - val_recall: 0.0967
# Epoch 2/40
# 802/802 [==============================] - 9s 11ms/step - loss: 1.1459 - accuracy: 0.5114 - precision: 0.6899 - recall: 0.2286 - val_loss: 1.0519 - val_accuracy: 0.5559 - val_precision: 0.7225 - val_recall: 0.3483
# Epoch 3/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.9542 - accuracy: 0.6124 - precision: 0.7409 - recall: 0.4268 - val_loss: 0.9086 - val_accuracy: 0.6268 - val_precision: 0.7514 - val_recall: 0.4594
# Epoch 4/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7835 - accuracy: 0.6871 - precision: 0.7801 - recall: 0.5601 - val_loss: 0.8127 - val_accuracy: 0.6705 - val_precision: 0.7607 - val_recall: 0.5510
# Epoch 5/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.6831 - accuracy: 0.7317 - precision: 0.8053 - recall: 0.6376 - val_loss: 0.7980 - val_accuracy: 0.6894 - val_precision: 0.7584 - val_recall: 0.5962
# Epoch 6/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.5942 - accuracy: 0.7703 - precision: 0.8259 - recall: 0.6985 - val_loss: 0.7603 - val_accuracy: 0.7113 - val_precision: 0.7683 - val_recall: 0.6440
# Epoch 7/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.5302 - accuracy: 0.7946 - precision: 0.8432 - recall: 0.7360 - val_loss: 0.7588 - val_accuracy: 0.7171 - val_precision: 0.7653 - val_recall: 0.6580
# Epoch 8/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.4789 - accuracy: 0.8159 - precision: 0.8558 - recall: 0.7699 - val_loss: 0.8143 - val_accuracy: 0.7121 - val_precision: 0.7511 - val_recall: 0.6630
# Epoch 9/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4204 - accuracy: 0.8385 - precision: 0.8716 - recall: 0.8006 - val_loss: 0.6994 - val_accuracy: 0.7486 - val_precision: 0.7890 - val_recall: 0.7013
# Epoch 10/40
# 802/802 [==============================] - 8s 11ms/step - loss: 0.3617 - accuracy: 0.8618 - precision: 0.8892 - recall: 0.8306 - val_loss: 0.6638 - val_accuracy: 0.7628 - val_precision: 0.7980 - val_recall: 0.7239
# Epoch 11/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.3267 - accuracy: 0.8697 - precision: 0.8949 - recall: 0.8471 - val_loss: 0.7252 - val_accuracy: 0.7564 - val_precision: 0.7935 - val_recall: 0.7200
# Epoch 12/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.3193 - accuracy: 0.8788 - precision: 0.9017 - recall: 0.8563 - val_loss: 0.6716 - val_accuracy: 0.7714 - val_precision: 0.7973 - val_recall: 0.7426
# Epoch 13/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.2750 - accuracy: 0.8948 - precision: 0.9138 - recall: 0.8772 - val_loss: 0.6668 - val_accuracy: 0.7783 - val_precision: 0.8026 - val_recall: 0.7563
# Epoch 14/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2275 - accuracy: 0.9123 - precision: 0.9279 - recall: 0.8987 - val_loss: 0.6933 - val_accuracy: 0.7796 - val_precision: 0.8037 - val_recall: 0.7587
# Epoch 15/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2021 - accuracy: 0.9255 - precision: 0.9392 - recall: 0.9113 - val_loss: 0.7207 - val_accuracy: 0.7836 - val_precision: 0.8021 - val_recall: 0.7669
# Epoch 16/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1783 - accuracy: 0.9342 - precision: 0.9451 - recall: 0.9229 - val_loss: 0.7116 - val_accuracy: 0.7962 - val_precision: 0.8115 - val_recall: 0.7796
# Epoch 17/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1602 - accuracy: 0.9431 - precision: 0.9519 - recall: 0.9338 - val_loss: 0.7837 - val_accuracy: 0.7804 - val_precision: 0.7965 - val_recall: 0.7677
# Epoch 18/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1505 - accuracy: 0.9451 - precision: 0.9540 - recall: 0.9376 - val_loss: 1.1190 - val_accuracy: 0.7343 - val_precision: 0.7482 - val_recall: 0.7229
# Epoch 19/40
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1494 - accuracy: 0.9446 - precision: 0.9537 - recall: 0.9377 - val_loss: 0.7488 - val_accuracy: 0.7975 - val_precision: 0.8111 - val_recall: 0.7844
# Epoch 20/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1170 - accuracy: 0.9600 - precision: 0.9667 - recall: 0.9528 - val_loss: 0.7815 - val_accuracy: 0.7999 - val_precision: 0.8111 - val_recall: 0.7896
# Epoch 00020: early stopping
# 268/268 [==============================] - 2s 6ms/step - loss: 0.8701 - accuracy: 0.7986 - precision: 0.8093 - recall: 0.7885
#
# Test Acc. 79.86%
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78      1978
#            1       0.85      0.76      0.80      1957
#            2       0.85      0.83      0.84      2069
#            3       0.74      0.81      0.77      2011
#
#    micro avg       0.80      0.80      0.80      8015
#    macro avg       0.80      0.80      0.80      8015
# weighted avg       0.80      0.80      0.80      8015
#  samples avg       0.80      0.80      0.80      8015
#
# Confusion matrix
# [[1560  162   82  174]
#  [ 221 1495   66  175]
#  [  88   42 1722  217]
#  [ 159   62  166 1624]]

# %%
train_and_test_model(train_dataset, validate_dataset, X_train, save_to= './', epoch = 40, 
                     dense_layers_unit_array=[], learningRate=0.1,
                     startWithBatchNormalized=True, optimizer="SGD",dropOutRate=0.5,
                     activation="relu",
                     conv_layers_filters_array=[50,50,50,50],
                     conv_kernel_size_array=[3,3,3,3],
                     conv_strides_array=[1,1,1,1]
                    )
# Out:
# epoch: 40 ; epoch_denominator: 10.0
# patience: 10 ; isConstantLearningRate: False
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of GPU/CPU: 2
# num_of_dense_layers: 0
# num_of_conv_layers: 4
# conv_layer_filters[0]; unit:50
# conv_kernel[0]; unit:3
# conv_strides[0]; unit:1
# conv_layer_filters[1]; unit:50
# conv_kernel[1]; unit:3
# conv_strides[1]; unit:1
# conv_layer_filters[2]; unit:50
# conv_kernel[2]; unit:3
# conv_strides[2]; unit:1
# conv_layer_filters[3]; unit:50
# conv_kernel[3]; unit:3
# conv_strides[3]; unit:1
# learningRate: 0.1
# isBatchNormalized: False ; dropOutRate: 0.5
# startWithBatchNormalized: True
# optimizer: SGD ; activation: relu
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 3738, 1)           4
# _________________________________________________________________
# conv_0 (Conv1D)              (None, 3738, 50)          200
# _________________________________________________________________
# pool_0 (MaxPooling1D)        (None, 1869, 50)          0
# _________________________________________________________________
# conv_1 (Conv1D)              (None, 1869, 50)          7550
# _________________________________________________________________
# pool_1 (MaxPooling1D)        (None, 934, 50)           0
# _________________________________________________________________
# conv_2 (Conv1D)              (None, 934, 50)           7550
# _________________________________________________________________
# pool_2 (MaxPooling1D)        (None, 467, 50)           0
# _________________________________________________________________
# conv_3 (Conv1D)              (None, 467, 50)           7550
# _________________________________________________________________
# pool_3 (MaxPooling1D)        (None, 233, 50)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 11650)             0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 46604
# _________________________________________________________________
# activation (Activation)      (None, 4)                 0
# =================================================================
# Total params: 69,458
# Trainable params: 69,456
# Non-trainable params: 2
# _________________________________________________________________
# Epoch 1/40
# 802/802 [==============================] - 14s 13ms/step - loss: 1.3721 - accuracy: 0.3076 - precision: 0.4125 - recall: 0.0120 - val_loss: 1.3119 - val_accuracy: 0.3837 - val_precision: 0.5980 - val_recall: 0.0681
# Epoch 2/40
# 802/802 [==============================] - 9s 11ms/step - loss: 1.1957 - accuracy: 0.4676 - precision: 0.6717 - recall: 0.1671 - val_loss: 1.1026 - val_accuracy: 0.5253 - val_precision: 0.6868 - val_recall: 0.3163
# Epoch 3/40
# 802/802 [==============================] - 9s 12ms/step - loss: 1.0047 - accuracy: 0.5811 - precision: 0.7236 - recall: 0.3714 - val_loss: 0.9863 - val_accuracy: 0.5893 - val_precision: 0.7696 - val_recall: 0.3514
# Epoch 4/40
# 802/802 [==============================] - 9s 12ms/step - loss: 0.8583 - accuracy: 0.6470 - precision: 0.7611 - recall: 0.5043 - val_loss: 0.9970 - val_accuracy: 0.5970 - val_precision: 0.6877 - val_recall: 0.4837
# Epoch 5/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.7618 - accuracy: 0.6950 - precision: 0.7827 - recall: 0.5809 - val_loss: 0.9215 - val_accuracy: 0.6395 - val_precision: 0.7210 - val_recall: 0.5457
# Epoch 6/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.6882 - accuracy: 0.7285 - precision: 0.8023 - recall: 0.6375 - val_loss: 1.0089 - val_accuracy: 0.6228 - val_precision: 0.6783 - val_recall: 0.5636
# Epoch 7/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.6158 - accuracy: 0.7590 - precision: 0.8190 - recall: 0.6852 - val_loss: 0.8429 - val_accuracy: 0.6818 - val_precision: 0.7362 - val_recall: 0.6106
# Epoch 8/40
# 802/802 [==============================] - 9s 12ms/step - loss: 0.5429 - accuracy: 0.7839 - precision: 0.8403 - recall: 0.7276 - val_loss: 0.7943 - val_accuracy: 0.6960 - val_precision: 0.7507 - val_recall: 0.6436
# Epoch 9/40
# 802/802 [==============================] - 9s 12ms/step - loss: 0.5026 - accuracy: 0.8096 - precision: 0.8509 - recall: 0.7584 - val_loss: 0.8372 - val_accuracy: 0.6910 - val_precision: 0.7338 - val_recall: 0.6502
# Epoch 10/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.4660 - accuracy: 0.8220 - precision: 0.8623 - recall: 0.7797 - val_loss: 0.7331 - val_accuracy: 0.7281 - val_precision: 0.7753 - val_recall: 0.6794
# Epoch 11/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.4152 - accuracy: 0.8434 - precision: 0.8770 - recall: 0.8097 - val_loss: 0.9323 - val_accuracy: 0.6853 - val_precision: 0.7172 - val_recall: 0.6441
# Epoch 12/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.3925 - accuracy: 0.8509 - precision: 0.8784 - recall: 0.8192 - val_loss: 0.7927 - val_accuracy: 0.7316 - val_precision: 0.7635 - val_recall: 0.6997
# Epoch 13/40
# 802/802 [==============================] - 9s 12ms/step - loss: 0.3325 - accuracy: 0.8726 - precision: 0.8971 - recall: 0.8476 - val_loss: 0.6952 - val_accuracy: 0.7627 - val_precision: 0.7894 - val_recall: 0.7306
# Epoch 14/40
# 802/802 [==============================] - 9s 12ms/step - loss: 0.2921 - accuracy: 0.8901 - precision: 0.9117 - recall: 0.8706 - val_loss: 0.7781 - val_accuracy: 0.7536 - val_precision: 0.7758 - val_recall: 0.7297
# Epoch 15/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.2762 - accuracy: 0.8954 - precision: 0.9129 - recall: 0.8778 - val_loss: 0.7434 - val_accuracy: 0.7649 - val_precision: 0.7855 - val_recall: 0.7397
# Epoch 16/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.2450 - accuracy: 0.9087 - precision: 0.9242 - recall: 0.8929 - val_loss: 0.7630 - val_accuracy: 0.7650 - val_precision: 0.7842 - val_recall: 0.7456
# Epoch 17/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.2101 - accuracy: 0.9227 - precision: 0.9357 - recall: 0.9091 - val_loss: 0.7901 - val_accuracy: 0.7734 - val_precision: 0.7873 - val_recall: 0.7567
# Epoch 18/40
# 802/802 [==============================] - 9s 12ms/step - loss: 0.1950 - accuracy: 0.9284 - precision: 0.9386 - recall: 0.9170 - val_loss: 0.8053 - val_accuracy: 0.7751 - val_precision: 0.7922 - val_recall: 0.7571
# Epoch 19/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1790 - accuracy: 0.9350 - precision: 0.9443 - recall: 0.9242 - val_loss: 0.8286 - val_accuracy: 0.7725 - val_precision: 0.7854 - val_recall: 0.7600
# Epoch 20/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1514 - accuracy: 0.9435 - precision: 0.9515 - recall: 0.9355 - val_loss: 0.8569 - val_accuracy: 0.7738 - val_precision: 0.7879 - val_recall: 0.7624
# Epoch 21/40
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1611 - accuracy: 0.9414 - precision: 0.9503 - recall: 0.9333 - val_loss: 0.8476 - val_accuracy: 0.7806 - val_precision: 0.7904 - val_recall: 0.7675
# Epoch 22/40
# 802/802 [==============================] - 9s 12ms/step - loss: 0.1208 - accuracy: 0.9554 - precision: 0.9626 - recall: 0.9504 - val_loss: 0.8501 - val_accuracy: 0.7860 - val_precision: 0.7978 - val_recall: 0.7749
# Epoch 23/40
# 802/802 [==============================] - 9s 12ms/step - loss: 0.1021 - accuracy: 0.9655 - precision: 0.9704 - recall: 0.9600 - val_loss: 0.9228 - val_accuracy: 0.7821 - val_precision: 0.7912 - val_recall: 0.7729
# Epoch 00023: early stopping
# 268/268 [==============================] - 2s 7ms/step - loss: 0.8993 - accuracy: 0.7928 - precision: 0.8031 - recall: 0.7865
#
# Test Acc. 79.28%
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76      1978
#            1       0.79      0.83      0.81      1957
#            2       0.87      0.82      0.84      2069
#            3       0.72      0.81      0.76      2011
#
#    micro avg       0.79      0.79      0.79      8015
#    macro avg       0.80      0.79      0.79      8015
# weighted avg       0.80      0.79      0.79      8015
#  samples avg       0.79      0.79      0.79      8015
#
# Confusion matrix
# [[1418  247   71  242]
#  [ 140 1618   47  152]
#  [  84   52 1692  241]
#  [ 122  120  143 1626]]

# %%
train_and_test_model(train_dataset, validate_dataset, X_train, save_to= './', epoch = 80, 
                     dense_layers_unit_array=[], learningRate=0.001,
                     startWithBatchNormalized=False, optimizer="Adam",dropOutRate=0.2,
                     activation="relu",
                     conv_layers_filters_array=[50,50,50,50],
                     conv_kernel_size_array=[3,3,3,3],
                     conv_strides_array=[1,1,1,1],
                     patience=20
                    )
# Out:
# epoch: 80 ; epoch_denominator: 10.0
# patience: 20 ; isConstantLearningRate: False
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of GPU/CPU: 2
# num_of_dense_layers: 0
# num_of_conv_layers: 4
# conv_layer_filters[0]; unit:50
# conv_kernel[0]; unit:3
# conv_strides[0]; unit:1
# conv_layer_filters[1]; unit:50
# conv_kernel[1]; unit:3
# conv_strides[1]; unit:1
# conv_layer_filters[2]; unit:50
# conv_kernel[2]; unit:3
# conv_strides[2]; unit:1
# conv_layer_filters[3]; unit:50
# conv_kernel[3]; unit:3
# conv_strides[3]; unit:1
# learningRate: 0.001
# isBatchNormalized: False ; dropOutRate: 0.2
# startWithBatchNormalized: False
# optimizer: Adam ; activation: relu
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_0 (Conv1D)              (None, 3738, 50)          200
# _________________________________________________________________
# pool_0 (MaxPooling1D)        (None, 1869, 50)          0
# _________________________________________________________________
# conv_1 (Conv1D)              (None, 1869, 50)          7550
# _________________________________________________________________
# pool_1 (MaxPooling1D)        (None, 934, 50)           0
# _________________________________________________________________
# conv_2 (Conv1D)              (None, 934, 50)           7550
# _________________________________________________________________
# pool_2 (MaxPooling1D)        (None, 467, 50)           0
# _________________________________________________________________
# conv_3 (Conv1D)              (None, 467, 50)           7550
# _________________________________________________________________
# pool_3 (MaxPooling1D)        (None, 233, 50)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 11650)             0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 46604
# _________________________________________________________________
# activation (Activation)      (None, 4)                 0
# =================================================================
# Total params: 69,454
# Trainable params: 69,454
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/80
# 802/802 [==============================] - 14s 13ms/step - loss: 3.2379 - accuracy: 0.3057 - precision: 0.3055 - recall: 0.0972 - val_loss: 1.3297 - val_accuracy: 0.3868 - val_precision: 0.5466 - val_recall: 0.0475
# Epoch 2/80
# 802/802 [==============================] - 9s 11ms/step - loss: 1.3072 - accuracy: 0.4132 - precision: 0.6142 - recall: 0.0732 - val_loss: 1.2867 - val_accuracy: 0.4631 - val_precision: 0.6018 - val_recall: 0.1711
# Epoch 3/80
# 802/802 [==============================] - 9s 11ms/step - loss: 1.1888 - accuracy: 0.4904 - precision: 0.6881 - recall: 0.1974 - val_loss: 1.2159 - val_accuracy: 0.4668 - val_precision: 0.6130 - val_recall: 0.2227
# Epoch 4/80
# 802/802 [==============================] - 8s 11ms/step - loss: 1.0787 - accuracy: 0.5440 - precision: 0.7050 - recall: 0.3104 - val_loss: 1.1059 - val_accuracy: 0.5389 - val_precision: 0.6655 - val_recall: 0.3617
# Epoch 5/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.9577 - accuracy: 0.6063 - precision: 0.7484 - recall: 0.4100 - val_loss: 1.0371 - val_accuracy: 0.5870 - val_precision: 0.6878 - val_recall: 0.4505
# Epoch 6/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.8728 - accuracy: 0.6499 - precision: 0.7588 - recall: 0.4984 - val_loss: 1.0021 - val_accuracy: 0.6082 - val_precision: 0.6882 - val_recall: 0.4943
# Epoch 7/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.7983 - accuracy: 0.6822 - precision: 0.7768 - recall: 0.5577 - val_loss: 0.9589 - val_accuracy: 0.6220 - val_precision: 0.7158 - val_recall: 0.5085
# Epoch 8/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.6912 - accuracy: 0.7245 - precision: 0.8034 - recall: 0.6292 - val_loss: 0.9050 - val_accuracy: 0.6655 - val_precision: 0.7318 - val_recall: 0.5871
# Epoch 9/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.6192 - accuracy: 0.7581 - precision: 0.8238 - recall: 0.6793 - val_loss: 0.8999 - val_accuracy: 0.6662 - val_precision: 0.7240 - val_recall: 0.6061
# Epoch 10/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.5528 - accuracy: 0.7833 - precision: 0.8369 - recall: 0.7186 - val_loss: 0.8795 - val_accuracy: 0.6948 - val_precision: 0.7411 - val_recall: 0.6388
# Epoch 11/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.4753 - accuracy: 0.8153 - precision: 0.8611 - recall: 0.7674 - val_loss: 0.8956 - val_accuracy: 0.6945 - val_precision: 0.7323 - val_recall: 0.6522
# Epoch 12/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.4214 - accuracy: 0.8362 - precision: 0.8765 - recall: 0.7943 - val_loss: 0.8744 - val_accuracy: 0.7134 - val_precision: 0.7503 - val_recall: 0.6772
# Epoch 13/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.3805 - accuracy: 0.8549 - precision: 0.8872 - recall: 0.8194 - val_loss: 0.8999 - val_accuracy: 0.7151 - val_precision: 0.7474 - val_recall: 0.6839
# Epoch 14/80
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3420 - accuracy: 0.8714 - precision: 0.9011 - recall: 0.8418 - val_loss: 0.9116 - val_accuracy: 0.7244 - val_precision: 0.7533 - val_recall: 0.6940
# Epoch 15/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.3440 - accuracy: 0.8714 - precision: 0.8995 - recall: 0.8445 - val_loss: 0.9412 - val_accuracy: 0.7214 - val_precision: 0.7462 - val_recall: 0.6959
# Epoch 16/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.2770 - accuracy: 0.8958 - precision: 0.9210 - recall: 0.8703 - val_loss: 0.9427 - val_accuracy: 0.7267 - val_precision: 0.7511 - val_recall: 0.7041
# Epoch 17/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.2541 - accuracy: 0.9109 - precision: 0.9312 - recall: 0.8894 - val_loss: 0.9724 - val_accuracy: 0.7245 - val_precision: 0.7457 - val_recall: 0.7038
# Epoch 18/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.2362 - accuracy: 0.9164 - precision: 0.9342 - recall: 0.8976 - val_loss: 0.9788 - val_accuracy: 0.7368 - val_precision: 0.7570 - val_recall: 0.7171
# Epoch 19/80
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1977 - accuracy: 0.9346 - precision: 0.9483 - recall: 0.9180 - val_loss: 1.0100 - val_accuracy: 0.7408 - val_precision: 0.7584 - val_recall: 0.7216
# Epoch 20/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1768 - accuracy: 0.9439 - precision: 0.9572 - recall: 0.9301 - val_loss: 1.0187 - val_accuracy: 0.7418 - val_precision: 0.7571 - val_recall: 0.7242
# Epoch 21/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1774 - accuracy: 0.9430 - precision: 0.9561 - recall: 0.9313 - val_loss: 1.0435 - val_accuracy: 0.7437 - val_precision: 0.7618 - val_recall: 0.7295
# Epoch 22/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1576 - accuracy: 0.9555 - precision: 0.9648 - recall: 0.9433 - val_loss: 1.0831 - val_accuracy: 0.7441 - val_precision: 0.7599 - val_recall: 0.7291
# Epoch 23/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1344 - accuracy: 0.9630 - precision: 0.9709 - recall: 0.9529 - val_loss: 1.1167 - val_accuracy: 0.7463 - val_precision: 0.7602 - val_recall: 0.7322
# Epoch 24/80
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1217 - accuracy: 0.9682 - precision: 0.9755 - recall: 0.9611 - val_loss: 1.1831 - val_accuracy: 0.7457 - val_precision: 0.7621 - val_recall: 0.7352
# Epoch 25/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1290 - accuracy: 0.9640 - precision: 0.9710 - recall: 0.9553 - val_loss: 1.1621 - val_accuracy: 0.7454 - val_precision: 0.7593 - val_recall: 0.7336
# Epoch 26/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1095 - accuracy: 0.9713 - precision: 0.9786 - recall: 0.9640 - val_loss: 1.1800 - val_accuracy: 0.7462 - val_precision: 0.7596 - val_recall: 0.7342
# Epoch 27/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.0989 - accuracy: 0.9770 - precision: 0.9824 - recall: 0.9710 - val_loss: 1.1995 - val_accuracy: 0.7483 - val_precision: 0.7604 - val_recall: 0.7363
# Epoch 28/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.0926 - accuracy: 0.9794 - precision: 0.9848 - recall: 0.9729 - val_loss: 1.2235 - val_accuracy: 0.7494 - val_precision: 0.7611 - val_recall: 0.7392
# Epoch 29/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.0842 - accuracy: 0.9822 - precision: 0.9872 - recall: 0.9771 - val_loss: 1.2530 - val_accuracy: 0.7492 - val_precision: 0.7602 - val_recall: 0.7402
# Epoch 30/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.0780 - accuracy: 0.9846 - precision: 0.9893 - recall: 0.9807 - val_loss: 1.2760 - val_accuracy: 0.7501 - val_precision: 0.7612 - val_recall: 0.7423
# Epoch 31/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.0723 - accuracy: 0.9874 - precision: 0.9904 - recall: 0.9826 - val_loss: 1.3032 - val_accuracy: 0.7516 - val_precision: 0.7617 - val_recall: 0.7433
# Epoch 32/80
# 802/802 [==============================] - 9s 11ms/step - loss: 0.0677 - accuracy: 0.9891 - precision: 0.9916 - recall: 0.9847 - val_loss: 1.3192 - val_accuracy: 0.7541 - val_precision: 0.7637 - val_recall: 0.7461
# Epoch 00032: early stopping
# 268/268 [==============================] - 2s 7ms/step - loss: 1.3980 - accuracy: 0.7603 - precision: 0.7680 - recall: 0.7517
#
# Test Acc. 76.03%
#               precision    recall  f1-score   support
#
#            0       0.77      0.67      0.72      1978
#            1       0.75      0.79      0.77      1957
#            2       0.80      0.83      0.81      2069
#            3       0.71      0.75      0.73      2011
#
#    micro avg       0.76      0.76      0.76      8015
#    macro avg       0.76      0.76      0.76      8015
# weighted avg       0.76      0.76      0.76      8015
#  samples avg       0.76      0.76      0.76      8015
#
# Confusion matrix
# [[1322  274  134  248]
#  [ 153 1552   87  165]
#  [  79   87 1707  196]
#  [ 153  145  200 1513]]
